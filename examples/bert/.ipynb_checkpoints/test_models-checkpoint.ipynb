# %% [markdown]
# # Bert

# %%
# 初始化
import sys
root_dir='/Users/guoqiang/Documents/wang/research/wudao/'

sys.path.append(root_dir)
from data_utils.BertDataset import BertDataset
from nets.BertEmbeddings import WordPosSegEmbedding
from nets.encoders import TransformerEncoder
from nets.targets import BertTarget
from model_bert import Model
import glob
from utils.struct_nav import str2tokenizer, str2embedding, str2encoder, str2target
from arguments import *
import train_utils.BertTrainer as trainer

isTEST = 1  # 测试模式，模型会读取./data/train_data/test.json作为输入数据
model_config_path = "./config/tiny_config.json"  # 加载预先调好的模型参数，默认为BERT基础版。如需自行设置参数请将此变量设置为空值""


print("加载config/settings.py里的超参数(如果使用预加载的模型参数，此文件里相关参数会被覆盖)")
args = build_args(root_dir=root_dir)
if model_config_path:
    print("当前模型从%s里加载模型参数" % model_config_path)
    args = load_hyperparam(args, config_path=model_config_path)
if isTEST:
    print("当前模型处于测试模式，会自动加载../data/train_data/test.json作为输入数据")
    args = load_hyperparam(args, config_path="./config/test_config.json")
else:
    print("当前模型处于正常模式")
    
    

args.file_types=['json']
if __name__=='__main__':
    print("构建数据集")
    print(args.preprocess_num)
    tokenizer = str2tokenizer[args.tokenizer](args)
    args.tokenizer = tokenizer
    dataset = BertDataset(args, tokenizer.vocab, tokenizer)
    
    #dataset.build_and_save(1,merge=True,file_preproces_dist=True)
    #
    print("建立模型的结构")
    embedding = str2embedding[args.embedding](args, len(args.tokenizer.vocab))
    encoder = str2encoder[args.encoder](args)
    target = str2target[args.target](args, len(args.tokenizer.vocab))
    model_struct = Model(args, embedding, encoder, target)
    # model_struct
    print("模型总参数量: ")
    get_total_params_num_from_model(model_struct)
    
    print("训练...")
    trainer.train_and_validate(args, model_struct)
# Out:
# 加载config/settings.py里的超参数(如果使用预加载的模型参数，此文件里相关参数会被覆盖)
# 无可用的GPU, 已自动转成CPU模式
# 当前模型从./config/tiny_config.json里加载模型参数
# 当前模型处于测试模式，会自动加载../data/train_data/test.json作为输入数据
# 构建数据集
# 8
# avaiable training files:1
# 建立模型的结构
# 模型总参数量:
# 5,926,154 total parameters.
# 5,926,154 training parameters.
# 训练...
# Worker is training ...
# 1
# |        5/1000000000 steps|  6211.32 tokens/s| loss   10.67| loss_mlm: 9.982| loss_sp: 0.691| acc_mlm: 0.000| acc_sp: 0.534
# 输入的处理后文本：
# [CLS]，补足制度短板；注重[MASK]足企业实际，充分吸[MASK]企业好的做法和管理[MASK]验，提炼为[MASK]度规定[MASK][MASK]求指[MASK]性、可操作性强。3。问：《通知[MASK]主要在哪些方[MASK]进[MASK]了修订？[SEP]答：《通知[MASK]包括六个部分内容，覆盖事前、事中  和  事后的关键[MASK]节。较原有制度的[MASK]化主[MASK][MASK]现在[MASK] ##郡 几个 ##隍 面。[SEP]
#
# 填入预测词后的文本：
# [CLS]，补足制度短板；注重 ##侶 足企业实际，充分吸 105 企业好的做法和管理 ##佶 验，提炼为 ##辉 度规定 ##牦   喟  求指  遒  性、可操作性强。3。问：《通知 ##簧 主要在哪些方 いします进  懦  了修订？[SEP]答：《通知 ##呗 包括六个部分内容，覆盖事前、事中  濯  事后的关键##580节。较原有制度的  劏  化主##key ##] 现在  结  simon几个 ##鹰 面。[SEP]
#
# 原始文本(目标文本)
# [CLS]，补足制度短板；注重  立  足企业实际，充分吸  收  企业好的做法和管理  经  验，提炼为  制  度规定  ，    力  求指  导  性、可操作性强。3。问：《通知  》  主要在哪些方  面  进  行  了修订？[SEP]答：《通知  》  包括六个部分内容，覆盖事前、事中  和  事后的关键  环  节。较原有制度的  变  化主  要    体  现在  以    下  几个  方  面。[SEP]
#
#
# |       10/1000000000 steps| 41269.57 tokens/s| loss   10.66| loss_mlm: 9.980| loss_sp: 0.679| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]投[MASK]10亿美元在印[MASK]帮助小企业开展在线业务。印度贸易部长皮[MASK]什·戈[MASK]尔(pi##yu##sh##go##ya##l)[MASK]新[MASK][MASK]的一次安全会[MASK]上表示：[MASK]他们可[MASK]已经投 6991了10亿美元[unused59]但[MASK]果他们每年造成10亿[MASK]元的损失，[MASK]他们就必须[MASK]供10亿美元[MASK]资金。[SEP]亚马逊将在2014年承诺[MASK]55亿[MASK]元投资基础上，[SEP]
#
# 填入预测词后的文本：
# [CLS]投 ##ᅭ 10亿美元在印 ##勢 帮助小企业开展在线业务。印度贸易部长皮  桓  什·戈  峡  尔(pi##yu##sh##go##ya##l)  遒  新 ##俟   垣  的一次安全会  遒  上表示： ##喟 他们可  瀑  已经投  呦  了10亿美元 1885但 ##钩 果他们每年造成10亿  苞  元的损失，model他们就必须  遒  供10亿美元 ##佶 资金。[SEP]亚马逊将在2014年承诺##58055亿  觊  元投资基础上，[SEP]
#
# 原始文本(目标文本)
# [CLS]投  资  10亿美元在印  度  帮助小企业开展在线业务。印度贸易部长皮  尤  什·戈  亚  尔(pi##yu##sh##go##ya##l)  在  新  德    里  的一次安全会  议  上表示：[UNK]他们可  能  已经投  入  了10亿美元  。  但  如  果他们每年造成10亿  美  元的损失，  那  他们就必须  提  供10亿美元  的  资金。[SEP]亚马逊将在2014年承诺  的  55亿  美  元投资基础上，[SEP]
#
#
# |       15/1000000000 steps| 156509.16 tokens/s| loss   10.66| loss_mlm: 9.976| loss_sp: 0.686| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS][MASK][MASK]子有着不同的场[MASK][MASK]在星巴克的各大门店都有贩售[MASK]  ！  [MASK]幸[MASK]酪杯不只是  星  巴克，瑞幸今年也推出了[MASK]年马[MASK]杯。小时候看[MASK]猫和老鼠》，[SEP][MASK]瑞最喜欢的就是奶酪，恨不得住[MASK]奶[MASK]做的房子里。[MASK]想到 ##蔷 个新年，瑞幸[MASK]它实现了这个愿望，三角形的奶酪杯里面还藏着一[MASK]小老鼠，[SEP]
#
# 填入预测词后的文本：
# [CLS] ##佶  ##低 子有着不同的场  遒   ##侶 在星巴克的各大门店都有贩售 ##˚  ##瘍   人  幸  旖  酪杯不只是 ##喺 巴克，瑞幸今年也推出了 ##黯 年马  遒  杯。小时候看 ##侶 猫和老鼠》，[SEP]  劏  瑞最喜欢的就是奶酪，恨不得住  侃  奶  掲  做的房子里。  檻  想到 ##拱 个新年，瑞幸  厌  它实现了这个愿望，三角形的奶酪杯里面还藏着一##cept小老鼠，[SEP]
#
# 原始文本(目标文本)
# [CLS]  的    杯  子有着不同的场  景    ，  在星巴克的各大门店都有贩售  哦    ！    瑞  幸  奶  酪杯不只是  星  巴克，瑞幸今年也推出了  鼠  年马  克  杯。小时候看  《  猫和老鼠》，[SEP]  杰  瑞最喜欢的就是奶酪，恨不得住  进  奶  酪  做的房子里。  没  想到  这  个新年，瑞幸  帮  它实现了这个愿望，三角形的奶酪杯里面还藏着一  只  小老鼠，[SEP]
#
#
# |       20/1000000000 steps| 139131.80 tokens/s| loss   10.68| loss_mlm: 9.989| loss_sp: 0.691| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]是[MASK]重的。文化传播是需要无数人努力的一件大事[MASK]而我只是[MASK]了我热爱的一[MASK]小[MASK]。当我知道有这么多外国朋友看到我的视频[MASK][MASK]欢我的视频，能更加[MASK]解中国，[SEP]我觉得很[MASK]豪  鶴  [UNK]拍[MASK][MASK]频是我热爱的事情[MASK]每[MASK]好一个视频都[MASK]  有  一种满足感[UNK]问当[MASK]开始[MASK]摄视频的初衷是怎样的[MASK][SEP]
#
# 填入预测词后的文本：
# [CLS]是 ##ᅭ 重的。文化传播是需要无数人努力的一件大事 ##佶 而我只是 ##这 了我热爱的一 ##臺 小 ##勢 。当我知道有这么多外国朋友看到我的视频  嘭    雀  欢我的视频，能更加 ##牦 解中国，[SEP]我觉得很##ject豪[unused85][UNK]拍##don  檻  频是我热爱的事情 ##呗 每 ##霆 好一个视频都  頑   ##傍 一种满足感[UNK]问当 ##呗 开始 2016摄视频的初衷是怎样的  淒  [SEP]
#
# 原始文本(目标文本)
# [CLS]是  沉  重的。文化传播是需要无数人努力的一件大事  ，  而我只是  做  了我热爱的一  件  小  事  。当我知道有这么多外国朋友看到我的视频  、    喜  欢我的视频，能更加  了  解中国，[SEP]我觉得很  自  豪  。  [UNK]拍  摄    视  频是我热爱的事情  ，  每  拍  好一个视频都  会    有  一种满足感[UNK]问当  初  开始  拍  摄视频的初衷是怎样的  ？  [SEP]
#
#
# |       25/1000000000 steps| 134079.77 tokens/s| loss   10.62| loss_mlm: 9.940| loss_sp: 0.677| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS][MASK]  士  康是苹果公司iphone的 ##∶ 要组装商。[SEP]随着  消  费[MASK]使用[MASK]能手机的时间延长[MASK]以及来自提供低价[MASK]机的中国制造商的竞争加剧，iphone[MASK]销售一直在放缓。富士康[MASK]事[MASK]刘扬伟去[MASK]曾表示，[SEP]
#
# 填入预测词后的文本：
# [CLS] ##佶  ##构 康是苹果公司iphone的 ##叨 要组装商。[SEP]随着 ##虫 费 ##晰 使用##580能手机的时间延长 ##ｂ 以及来自提供低价  遒  机的中国制造商的竞争加剧，iphone ##硒 销售一直在放缓。富士康  檻  事  慮  刘扬伟去  濯  曾表示，[SEP]
#
# 原始文本(目标文本)
# [CLS]  富    士  康是苹果公司iphone的  主  要组装商。[SEP]随着  消  费  者  使用  智  能手机的时间延长  ，  以及来自提供低价  手  机的中国制造商的竞争加剧，iphone  的  销售一直在放缓。富士康  董  事  长  刘扬伟去  年  曾表示，[SEP]
#
#
# |       30/1000000000 steps| 148100.41 tokens/s| loss   10.65| loss_mlm: 9.977| loss_sp: 0.674| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]给好友浇水得福卡第2 ##紮 集福卡途径，是在蚂蚁森林[UNK]给[MASK]友浇[MASK]得福卡[UNK]。用户可[MASK]自[MASK]选择浇水  克  数，并[MASK]醒对方来，7天不收还能退回。[SEP]3运动集福卡第3个[MASK][MASK]  卡  途径是运动集福，[MASK]过这个功能要到1[MASK]17日才上[MASK]。我[MASK]可[MASK]在「[MASK]付宝运动」中走[MASK]线[MASK][MASK]满100步即领福卡。[SEP]
#
# 填入预测词后的文本：
# [CLS]给好友浇水得福卡第2 ##侶 集福卡途径，是在蚂蚁森林[UNK]给 ##瘍 友浇  桓  得福卡[UNK]。用户可 mod 自 ##佶 选择浇水  键  数，并 ##イト醒对方来，7天不收还能退回。[SEP]3运动集福卡第3个  觊    票    舟  途径是运动集福， ##腺 过这个功能要到1  喟  17日才上  圜  。我 ##峒 可 ##呗 在「 ##cn付宝运动」中走 2016线 ##弧   撥  满100步即领福卡。[SEP]
#
# 原始文本(目标文本)
# [CLS]给好友浇水得福卡第2  个  集福卡途径，是在蚂蚁森林[UNK]给  好  友浇  水  得福卡[UNK]。用户可  以  自  己  选择浇水  克  数，并  提  醒对方来，7天不收还能退回。[SEP]3运动集福卡第3个  集    福    卡  途径是运动集福，  不  过这个功能要到1  月  17日才上  线  。我  们  可  以  在「  支  付宝运动」中走  路  线  ，    走  满100步即领福卡。[SEP]
# |       35/1000000000 steps| 129685.91 tokens/s| loss   10.65| loss_mlm: 9.974| loss_sp: 0.677| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]现在的比  阈  特丽斯[MASK]主（pr##ince##ss##be[MASK]##ric##e）[MASK]尤金妮公主（pr##ince##sse##ug##en ##橋 [MASK]就不是[MASK]在职王室成员[UNK]，[SEP]  未  来哈里一家在加拿大[MASK]活时[MASK]安保费用将成为亟待解决[MASK]问题。或[MASK]  这  也就是[MASK]何加拿大政府[MASK]员此前也参加[MASK]1月13日英[MASK]王室特别会议的原因。[MASK]开资[MASK]显示，整个英国王室每[SEP]
#
# 填入预测词后的文本：
# [CLS]现在的比  hp 特丽斯 ##侶 主（pr##ince##ss##becurve##ric##e）  顫  尤金妮公主（pr##ince##sse##ug##en  線   ##⑩ 就不是 ##莠 在职王室成员[UNK]，[SEP]  貨  来哈里一家在加拿大  檻  活时  呐  安保费用将成为亟待解决 ##呗 问题。或 ##呗   晗  也就是  掲  何加拿大政府  檻  员此前也参加  檻  1月13日英 ##cn王室特别会议的原因。 ##霆 开资 ##羹 显示，整个英国王室每[SEP]
#
# 原始文本(目标文本)
# [CLS]现在的比  阿  特丽斯  公  主（pr##ince##ss##be ##at##ric##e）  和  尤金妮公主（pr##ince##sse##ug##en ##ie  ）  就不是[UNK]在职王室成员[UNK]，[SEP]  未  来哈里一家在加拿大  生  活时  的  安保费用将成为亟待解决  的  问题。或  许    这  也就是  为  何加拿大政府  官  员此前也参加  了  1月13日英  国  王室特别会议的原因。  公  开资  料  显示，整个英国王室每[SEP]
#
#
# |       40/1000000000 steps| 133769.60 tokens/s| loss   10.65| loss_mlm: 9.963| loss_sp: 0.689| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]表现优于行业；近[MASK]对低[MASK]白奶加大推广力度，[SEP][MASK]  配  消费需求变化趋[MASK]，看好公司##cal远[MASK]略布局。冷饮[MASK]续较[MASK][MASK]争力，高端新品升级[MASK][MASK]的明显结构性价格  增  量。奶粉渐平[MASK]，跨品类长远可期奶粉业务2019年增速  回  落，[MASK]业增长趋[MASK]稳，但高端升级趋势[MASK]著、国[MASK]品牌红利延续，伊利[SEP]
#
# 填入预测词后的文本：
# [CLS]表现优于行业；近 ##90对低 ##汩 白奶加大推广力度，[SEP]  咎   ##× 消费需求变化趋  у  ，看好公司##ude远  癒  略布局。冷饮 ##惰 续较 ##委   觊  争力，高端新品升级  艹    懦  的明显结构性价格  尉  量。奶粉渐平 ##糯 ，跨品类长远可期奶粉业务2019年增速  変  落，  檻  业增长趋  劏  稳，但高端升级趋势 ##▉ 著、国 ##涂 品牌红利延续，伊利[SEP]
#
# 原始文本(目标文本)
# [CLS]表现优于行业；近  期  对低  温  白奶加大推广力度，[SEP]  匹    配  消费需求变化趋  势  ，看好公司  长  远  战  略布局。冷饮  延  续较  强    竞  争力，高端新品升级  带    来  的明显结构性价格  增  量。奶粉渐平  稳  ，跨品类长远可期奶粉业务2019年增速  回  落，  行  业增长趋  平  稳，但高端升级趋势  显  著、国  产  品牌红利延续，伊利[SEP]
#
#
# |       45/1000000000 steps| 134094.11 tokens/s| loss   10.70| loss_mlm: 9.992| loss_sp: 0.705| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]自 ##锌 公司平时该做的、能做的[MASK]需要做的事情理一理，理理[MASK]楚再[MASK]。湖畔不[MASK]教大家怎么去[MASK][MASK]，而[MASK]教大家怎么把企业活  得  更久[MASK]活得更[MASK]久是很难的。 ##緬 烛[MASK]烧得长，[SEP]蜡烛的火芯一[MASK]得短[MASK]火[MASK]要烧得快，蜡烛[MASK]定亮。企业就是要把[MASK]这个规律：[MASK]企业，你想活得好，运动吧，[SEP]
#
# 填入预测词后的文本：
# [CLS]自 ##浄 公司平时该做的、能做的  遒  需要做的事情理一理，理理 ##佶 楚再 いします。湖畔不model教大家怎么去  绣    遒  ，而 274 教大家怎么把企业活 ##腭 更久tokichoi活得更  鞏  久是很难的。  島  烛  蜊  烧得长，[SEP]蜡烛的火芯一  喟  得短 ##淩 火  檻  要烧得快，蜡烛 ##愫 定亮。企业就是要把 ##谧 这个规律：  劏  企业，你想活得好，运动吧，[SEP]
#
# 原始文本(目标文本)
# [CLS]自  己  公司平时该做的、能做的  、  需要做的事情理一理，理理  清  楚再  说  。湖畔不  是  教大家怎么去  创    业  ，而  是  教大家怎么把企业活  得  更久  。  活得更  长  久是很难的。  蜡  烛  要  烧得长，[SEP]蜡烛的火芯一  定  得短  ；  火  芯  要烧得快，蜡烛  一  定亮。企业就是要把  握  这个规律：  好  企业，你想活得好，运动吧，[SEP]
#
#
# |       50/1000000000 steps| 147426.70 tokens/s| loss   10.73| loss_mlm: 10.012| loss_sp: 0.714| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]  发  展起精细的量子调[MASK]技[MASK]，[MASK]结合量子调控[MASK]信息技术，[SEP]人  类  迎[MASK][MASK]第二次量子革命。潘建伟指出，[MASK]类从对量子规律的[MASK][MASK][MASK][MASK]，到[MASK]量子状态的主动操纵 ##瀰 正如人类对生物学的认识，从孟德尔遗传定律到dna结构的伟大跨越。量子信息包括量子通[MASK]  、  量[MASK]计算和量子精  密  测量三方[SEP]
#
# 填入预测词后的文本：
# [CLS] 179 展起精细的量子调  喟  技##mber，##ために结合量子调控 1941信息技术，[SEP]人##ject迎 ##後 ##580第二次量子革命。潘建伟指出，  環  类从对量子规律的 ##澱  ##委   ゅ  financial，到 oct 量子状态的主动操纵  はお 正如人类对生物学的认识，从孟德尔遗传定律到dna结构的伟大跨越。量子信息包括量子通 ##佶 ##ted量 ##赐 计算和量子精 ##喱 测量三方[SEP]
#
# 原始文本(目标文本)
# [CLS]  发  展起精细的量子调  控  技  术  ，  而  结合量子调控  和  信息技术，[SEP]人  类  迎  来    了  第二次量子革命。潘建伟指出，  人  类从对量子规律的  被    动    观    测  ，到  对  量子状态的主动操纵  ，  正如人类对生物学的认识，从孟德尔遗传定律到dna结构的伟大跨越。量子信息包括量子通  信    、  量  子  计算和量子精  密  测量三方[SEP]
#
#
# |       55/1000000000 steps| 134902.36 tokens/s| loss   10.69| loss_mlm: 9.980| loss_sp: 0.705| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]以实[MASK]以低成本方式实现高性能侦察。超低轨  51 通常是指临近空间以上，且低于300千米高度的轨 ##嗒 [MASK]在超[MASK]轨道部署卫星，能  够  大[MASK]缩[MASK]成像距离，提供[MASK]学和[MASK]达性能，利用小卫星搭载成像载荷[MASK][MASK]达到目前世界领先[MASK]  成  [MASK]能[MASK]，卫星研制和发射成本也将大幅降低。[SEP]措[MASK][MASK]有变  动  ）[SEP]
#
# 填入预测词后的文本：
# [CLS]以实  驷  以低成本方式实现高性能侦察。超低轨 1941通常是指临近空间以上，且低于300千米高度的轨  啜   ##勢 在超  爪  轨道部署卫星，能 ##η 大 ##喟 缩  桓  成像距离，提供 ##⑩ 学和  ∀  达性能，利用小卫星搭载成像载荷  啜   ##勢 达到目前世界领先  龕   ##¼  ##rf能  桓  ，卫星研制和发射成本也将大幅降低。[SEP]措 ##委  ##咙 有变  渥  ）[SEP]
#
# 原始文本(目标文本)
# [CLS]以实  现  以低成本方式实现高性能侦察。超低轨  道  通常是指临近空间以上，且低于300千米高度的轨  道    。  在超  低  轨道部署卫星，能  够  大  幅  缩  短  成像距离，提供  光  学和  雷  达性能，利用小卫星搭载成像载荷  即    可  达到目前世界领先  的    成    像  能  力  ，卫星研制和发射成本也将大幅降低。[SEP]措  辞    略  有变  动  ）[SEP]
#
#
# |       60/1000000000 steps| 145438.54 tokens/s| loss   10.68| loss_mlm: 9.990| loss_sp: 0.694| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]新限塑令[UNK]要求[MASK]照禁限一批、[MASK]  數   ##逻 环一批、规范一[MASK]的思路，[MASK]2020年，[MASK]先在部分地区、部[MASK]领域[MASK]止限制部分[MASK]料制品的生  产  、[MASK]售[MASK]使用[MASK]禁止生产和销售厚度小于0.025毫米的  超  薄塑料购物袋[MASK][SEP]厚度小于0.01毫[MASK]的聚乙烯[MASK][MASK]地膜；禁止以医疗废物为原料制造塑料制品；[SEP]
#
# 填入预测词后的文本：
# [CLS]新限塑令[UNK]要求books照禁限一批、 ##娅   悩    咽  环一批、规范一 274 的思路， ##浄 2020年， 105 先在部分地区、部  遒  领域 274 止限制部分  遒  料制品的生  鍊  、  呐  售  懦  使用  蹂  禁止生产和销售厚度小于0.025毫米的 ##溃 薄塑料购物袋 274 [SEP]厚度小于0.01毫  q3 的聚乙烯 ##呗  ##籁 地膜；禁止以医疗废物为原料制造塑料制品；[SEP]
#
# 原始文本(目标文本)
# [CLS]新限塑令[UNK]要求  按  照禁限一批、  替    代    循  环一批、规范一  批  的思路，  到  2020年，  率  先在部分地区、部  分  领域  禁  止限制部分  塑  料制品的生  产  、  销  售  和  使用  。  禁止生产和销售厚度小于0.025毫米的  超  薄塑料购物袋  ；  [SEP]厚度小于0.01毫  米  的聚乙烯  农    用  地膜；禁止以医疗废物为原料制造塑料制品；[SEP]
# |       65/1000000000 steps| 146803.24 tokens/s| loss   10.68| loss_mlm: 10.004| loss_sp: 0.679| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]女坦克手更多的是一种巾帼不让须[MASK]的宣传。[MASK][MASK]  磕  苏[MASK]时代，[SEP]女坦克[MASK]  也  是要上战场的。这是  因  为卫国战争当[MASK]牺牲了太[MASK]的男性，所[MASK]有的时候，苏联女性也必须开着坦克去打击德国[MASK]略者。俄罗斯妇女的强壮体格，其他的[MASK][MASK][MASK]者民[MASK]也很难  效  仿。 ##惇 而[MASK]于第三代主战坦克以后[SEP]
#
# 填入预测词后的文本：
# [CLS]女坦克手更多的是一种巾帼不让须  ∀  的宣传。 105  105  ##镜 苏  普  时代，[SEP]女坦克 ##呗  ##oc是要上战场的。这是  挎  为卫国战争当  觊  牺牲了太[unused55]的男性，所  懦  有的时候，苏联女性也必须开着坦克去打击德国  咎  略者。俄罗斯妇女的强壮体格，其他的 ##cnfinancial##580者民 ##cn也很难 ##帕 仿。 ##淩 而  掲  于第三代主战坦克以后[SEP]
#
# 原始文本(目标文本)
# [CLS]女坦克手更多的是一种巾帼不让须  眉  的宣传。  当    然    在  苏  联  时代，[SEP]女坦克  手    也  是要上战场的。这是  因  为卫国战争当  中  牺牲了太  多  的男性，所  以  有的时候，苏联女性也必须开着坦克去打击德国  侵  略者。俄罗斯妇女的强壮体格，其他的  国    家    或  者民  族  也很难  效  仿。  然  而  对  于第三代主战坦克以后[SEP]
#
#
# |       70/1000000000 steps| 157574.16 tokens/s| loss   10.70| loss_mlm: 10.024| loss_sp: 0.681| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]发现两只手已经开始发黑。重[MASK]天日4月  19 日，[SEP]我在  灯  下  堆  察自己的手[MASK][SEP]
#
# 填入预测词后的文本：
# [CLS]发现两只手已经开始发黑。重##vel天日4月maggie日，[SEP]我在 ##呗 下  嚎  察自己的手 ##呗 [SEP]
#
# 原始文本(目标文本)
# [CLS]发现两只手已经开始发黑。重  见  天日4月  19 日，[SEP]我在  灯  下  观  察自己的手  ，  [SEP]
#
#
# |       75/1000000000 steps| 142520.79 tokens/s| loss   10.68| loss_mlm: 9.974| loss_sp: 0.710| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS][UNK]全球空白[MASK]推进技术就是[UNK]直流全电[MASK]进系统[UNK]。  马  伟明团[MASK][MASK]发成功的这面技术据说[MASK]先美国很多年[MASK]具有体[MASK]小[MASK]重量小和  q3 力大[MASK]优点。据说使用直流全电推进需要解决  好  短[MASK]保  护  的难题，[SEP]这项技  术  是[MASK]它国家所不[MASK]备的  。  值得注意的是，如[MASK]055级舰使用上了全电推进技术，[SEP]
#
# 填入预测词后的文本：
# [CLS][UNK]全球空白 179 推进技术就是[UNK]直流全电  ∀  进系统[UNK]。article伟明团  瀑    桓  发成功的这面技术据说  喟  先美国很多年  爪  具有体 ##侶 小 ##貨 重量小和 ##頓 力大 ##浄 优点。据说使用直流全电推进需要解决  攪  短  峡  保 ##溃 的难题，[SEP]这项技patrick是  瞰  它国家所不  喟  备的##del值得注意的是，如 ##呗 055级舰使用上了全电推进技术，[SEP]
#
# 原始文本(目标文本)
# [CLS][UNK]全球空白[UNK]推进技术就是[UNK]直流全电  推  进系统[UNK]。  马  伟明团  队    研  发成功的这面技术据说  领  先美国很多年  ，  具有体  系  小  、  重量小和  电  力大  等  优点。据说使用直流全电推进需要解决  好  短  路  保  护  的难题，[SEP]这项技  术  是  其  它国家所不  具  备的  。  值得注意的是，如  果  055级舰使用上了全电推进技术，[SEP]
#
#
# |       80/1000000000 steps| 147024.98 tokens/s| loss   10.66| loss_mlm: 9.969| loss_sp: 0.688| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS] ##踟 短信通知截图。[UNK]返[MASK]的手[MASK]是最先报案的时候去派出所[MASK]记，后来还[MASK] ##矿 个线上平台登记的，在之后就没什么消息了，[MASK][MASK]等到今年7[MASK]新闻消息说去户口[MASK][MASK]地的法院[MASK]登记一 ##街 ，[SEP]第六个  月  ：90%也行 ##潋 [UNK]一年后：50%也可以的[UNK][UNK][MASK]年后：算了，不记[MASK]这钱[MASK][MASK][UNK]1月8日，[SEP]
#
# 填入预测词后的文本：
# [CLS] ##漩 短信通知截图。[UNK]返  瀑  的手  爪  是最先报案的时候去派出所 ##佶 记，后来还 ##锄   鸿  个线上平台登记的，在之后就没什么消息了，books ##腭 等到今年7  フ  新闻消息说去户口  遒   105 地的法院 am09登记一angelababy，[SEP]第六个 ##裆 ：90%也行  梭  [UNK]一年后：50%也可以的[UNK][UNK] ##cn年后：算了，不记 ##da这钱 ##りの  估  [UNK]1月8日，[SEP]
#
# 原始文本(目标文本)
# [CLS]  的  短信通知截图。[UNK]返  钱  的手  续  是最先报案的时候去派出所  登  记，后来还  有    一  个线上平台登记的，在之后就没什么消息了，  一    直  等到今年7  月  新闻消息说去户口  所    在  地的法院  再  登记一  次  ，[SEP]第六个  月  ：90%也行[UNK][UNK]一年后：50%也可以的[UNK][UNK]  两  年后：算了，不记  得  这钱  了  [UNK][UNK]1月8日，[SEP]
#
#
# |       85/1000000000 steps| 139513.46 tokens/s| loss   10.66| loss_mlm: 9.954| loss_sp: 0.709| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]并于2010年[MASK]月至[MASK]年6月[MASK][MASK]光大金控资产管理有限公司股权董事。2015年3月至2018年10月担任中国光大集团股份公司副总经理，[SEP]中国光大银行[MASK]明[MASK]行行长、深圳[MASK]行行长，中国光 ##瘪 [MASK]行战略管理部总[MASK]理。2009年9月至[MASK]年[MASK][MASK]兼任中国光大集团股[MASK]公司（[MASK]其前[MASK][MASK]战略规划[MASK][MASK]经[SEP]
#
# 填入预测词后的文本：
# [CLS]并于2010年  啜  月至 ##ね 年6月##mberimage光大金控资产管理有限公司股权董事。2015年3月至2018年10月担任中国光大集团股份公司副总经理，[SEP]中国光大银行 ##呗 明  查  行行长、深圳  帐  行行长，中国光 ##焼   掲  行战略管理部总  厌  理。2009年9月至  檻  年 ##汩  ##呗 兼任中国光大集团股 ##霆 公司（ ##斡 其前  墾    觊  战略规划  檻    ゅ  经[SEP]
#
# 原始文本(目标文本)
# [CLS]并于2010年  4  月至 2017年6月  兼    任  光大金控资产管理有限公司股权董事。2015年3月至2018年10月担任中国光大集团股份公司副总经理，[SEP]中国光大银行  昆  明  分  行行长、深圳  分  行行长，中国光  大    银  行战略管理部总  经  理。2009年9月至 2017年  3    月  兼任中国光大集团股  份  公司（  及  其前  身    ）  战略规划  部    总  经[SEP]
#
#
# |       90/1000000000 steps| 131104.81 tokens/s| loss   10.68| loss_mlm: 9.998| loss_sp: 0.681| acc_mlm: 0.012| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]边  的  头发撇至耳后，露出了精致的下颚[MASK]条，  孽  穿一袭金亮色的[MASK]胸连衣裙搭配一双金亮色的恨天高，完[MASK]地呈现出了景甜 dell[MASK]亮[MASK]锁骨和修长的颈部线条，[MASK]上高跟[MASK]的她，[SEP]更是[MASK]长了腿部[MASK]条~[MASK]腰设计[MASK][MASK]胸[MASK]衣裙，勾勒出了景甜[MASK]盈盈一握的腰 ##凉 ，高开叉设[MASK]的抹胸连衣裙，[SEP]
#
# 填入预测词后的文本：
# [CLS]边  ∕  头发撇至耳后，露出了精致的下颚  ∀  条，  实  穿一袭金亮色的 ##ろう胸连衣裙搭配一双金亮色的恨天高，完  甌  地呈现出了景甜  稼    なと 亮  冗  锁骨和修长的颈部线条， ##rf上高跟  溝  的她，[SEP]更是  峡  长了腿部  めた 条~season腰设计 ##徜  ##ง 胸  遒  衣裙，勾勒出了景甜 ##籁 盈盈一握的腰  劏  ，高开叉设 ##cn的抹胸连衣裙，[SEP]
#
# 原始文本(目标文本)
# [CLS]边  的  头发撇至耳后，露出了精致的下颚  线  条，  身  穿一袭金亮色的  抹  胸连衣裙搭配一双金亮色的恨天高，完  美  地呈现出了景甜  那    漂  亮  的  锁骨和修长的颈部线条，  穿  上高跟  鞋  的她，[SEP]更是  拉  长了腿部  线  条~  收  腰设计  的    抹  胸  连  衣裙，勾勒出了景甜  那  盈盈一握的腰  肢  ，高开叉设  计  的抹胸连衣裙，[SEP]
#
#
# |       95/1000000000 steps| 141414.39 tokens/s| loss   10.62| loss_mlm: 9.917| loss_sp: 0.699| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]不能要求村委会对景[MASK]内的所有树木加以围蔽[MASK]  设  置警示标志。[SEP][MASK][MASK][MASK]为具有完全民事行为能力的成[MASK]人，[MASK]当充分预见[MASK][unused26]杨梅树采摘杨梅的危险性。该村村[MASK][MASK]约明文规定，村民[MASK]自觉维护村 sdk 体 ##女 各[MASK]财产利益，包括公共设施和绿化树木等，吴某私自上  委  [MASK]摘杨梅的行为，[MASK]反[SEP]
#
# 填入预测词后的文本：
# [CLS]不能要求村委会对景  遒  内的所有树木加以围蔽 1941  蘿  置警示标志。[SEP] いします  檻  ##580为具有完全民事行为能力的成 ##呗 人， ##贯 当充分预见 hbl  ##甕 杨梅树采摘杨梅的危险性。该村村  劏    帐  约明文规定，村民  掲  自觉维护村 ##視 体  亭  各  3c 财产利益，包括公共设施和绿化树木等，吴某私自上  讼   ##弧 摘杨梅的行为，  ゅ  反[SEP]
#
# 原始文本(目标文本)
# [CLS]不能要求村委会对景  区  内的所有树木加以围蔽  、    设  置警示标志。[SEP]  吴    某    作  为具有完全民事行为能力的成  年  人，  应  当充分预见  攀    爬  杨梅树采摘杨梅的危险性。该村村  规    民  约明文规定，村民  要  自觉维护村  集  体  的  各  项  财产利益，包括公共设施和绿化树木等，吴某私自上  树    采  摘杨梅的行为，  违  反[SEP]
# |      100/1000000000 steps| 144111.19 tokens/s| loss   10.67| loss_mlm: 9.977| loss_sp: 0.692| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]新京报记者在[MASK]宝山看  到  ，有市民[MASK][MASK]点就前[MASK]排队[MASK]候[MASK]ettoday，王刚、董浩、杨澜 ##兼 征夫妇、朱军、范曾、王为念、陈佩斯、朱时  阡  、谢红等[MASK]相继来此悼念。[SEP]原标题：演员王刚[MASK]念现场忆赵忠祥[MASK]他是我 ##撕 行[MASK]里的宗师[SEP]
#
# 填入预测词后的文本：
# [CLS]新京报记者在 ##瀅 宝山看  卑  ，有市民 105  ##瀰 点就前 1941排队 ##腭 候  喟    伴  ，王刚、董浩、杨澜 ##痪 征夫妇、朱军、范曾、王为念、陈佩斯、朱时 105 、谢红等 ##憎 相继来此悼念。[SEP]原标题：演员王刚  ㄅ  念现场忆赵忠祥  杉  他是我richard行 ##凛 里的宗师[SEP]
#
# 原始文本(目标文本)
# [CLS]新京报记者在  八  宝山看  到  ，有市民  六    七  点就前  来  排队  等  候  入    场  ，王刚、董浩、杨澜  吴  征夫妇、朱军、范曾、王为念、陈佩斯、朱时  茂  、谢红等  人  相继来此悼念。[SEP]原标题：演员王刚  悼  念现场忆赵忠祥  ：  他是我  们  行  业  里的宗师[SEP]
#
#
# |      105/1000000000 steps| 127429.05 tokens/s| loss   10.71| loss_mlm: 10.017| loss_sp: 0.690| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS][MASK]吉娜的好身材完全[MASK][MASK]出来，在裙摆的[MASK]置采用[MASK]不规则的流线型剪裁设计，更增添了  一  些不对称[MASK]美感，[SEP]尤[MASK]身材真惊艳。在  柢  [MASK]的选择上，吉娜选择了一[MASK]比较高的马 ##鰓 辫[MASK]将头发干净利落的扎在脑[MASK]，露出一张精致的面容。高马尾的发型能够[MASK][MASK]的凸显[MASK][MASK]，[MASK]时也非常符合[SEP]
#
# 填入预测词后的文本：
# [CLS] ##佶 吉娜的好身材完全 ##赃  ##侶 出来，在裙摆的  弈  置采用  瀾  不规则的流线型剪裁设计，更增添了 ##蟻 些不对称  遒  美感，[SEP]尤 ##祖 身材真惊艳。在##ject ##硒 的选择上，吉娜选择了一##580比较高的马 ##縴 辫 ##偻 将头发干净利落的扎在脑 ##抜 ，露出一张精致的面容。高马尾的发型能够 ##呗  いします的凸显 ##˚   查  ，  屏  时也非常符合[SEP]
#
# 原始文本(目标文本)
# [CLS]  将  吉娜的好身材完全  凸    显  出来，在裙摆的  位  置采用  了  不规则的流线型剪裁设计，更增添了  一  些不对称  的  美感，[SEP]尤  物  身材真惊艳。在  发    型  的选择上，吉娜选择了一  款  比较高的马  尾  辫  ，  将头发干净利落的扎在脑  后  ，露出一张精致的面容。高马尾的发型能够  很    好  的凸显  气    质  ，  同  时也非常符合[SEP]
#
#
# |      110/1000000000 steps| 126092.54 tokens/s| loss   10.68| loss_mlm: 10.003| loss_sp: 0.675| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]此次微信开[MASK]好友[MASK]量上限具体是[MASK]少。在很多人看来，[MASK][MASK]张小龙此番[MASK]讲，微信[MASK]大5000人  的  好[MASK]上线[MASK][MASK]  是  板上钉[MASK]。另一点，则在于发力微信短内容的创  咘  。[SEP]披露的最新成绩单显示[MASK]截[MASK]2020年1月5日[MASK]抖音日活跃用户[MASK]已经突破4亿。[MASK]然这个数字距离微信的仍有很大距离，[SEP]
#
# 填入预测词后的文本：
# [CLS]此次微信开  噠  好友  啜  量上限具体是 ##憤 少。在很多人看来， ##繡   人  张小龙此番 ##メ 讲，微信  孚  大5000人##ies好 ##勢 上线 ##佶  ##闡 ##rip板上钉  喟  。另一点，则在于发力微信短内容的创 ##抒 。[SEP]披露的最新成绩单显示  檻  截 ##燄 2020年1月5日 ##落 抖音日活跃用户  估  已经突破4亿。 llc 然这个数字距离微信的仍有很大距离，[SEP]
#
# 原始文本(目标文本)
# [CLS]此次微信开  放  好友  数  量上限具体是  多  少。在很多人看来，  结    合  张小龙此番  演  讲，微信  扩  大5000人  的  好  友  上线  已    经    是  板上钉  钉  。另一点，则在于发力微信短内容的创  作  。[SEP]披露的最新成绩单显示  ：  截  至  2020年1月5日  ，  抖音日活跃用户  数  已经突破4亿。  虽  然这个数字距离微信的仍有很大距离，[SEP]
#
#
# |      115/1000000000 steps| 128688.83 tokens/s| loss   10.65| loss_mlm: 9.953| loss_sp: 0.697| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS][MASK]行##day要克[MASK][MASK]目的、低水平的重复建设，要使  这  些从事集[MASK]电路的主体企业能够一步一[MASK]地从投资转向[MASK]营，在运[MASK]过程当中，除了  技  术要取[MASK]成[MASK]之外，[SEP]而且仅仅凭一[MASK][MASK]产线的产能，有的还实现不了现金[MASK]为正，在相当长时间[MASK]实[MASK]不[MASK]企业的[MASK]利。在企业不能盈利的情况下，[SEP]
#
# 填入预测词后的文本：
# [CLS]  蹂  行  ほ  要克 ##牦  ##繡 目的、低水平的重复建设，要使  勸  些从事集 ##˚ 电路的主体企业能够一步一  駄  地从投资转向 ##慶 营，在运  遒  过程当中，除了  瓏  术要取 いします成 ##牺 之外，[SEP]而且仅仅凭一  屏   exe 产线的产能，有的还实现不了现金 ##ง 为正，在相当长时间 ##呗 实 ##籁 不  氧  企业的 ##呗 利。在企业不能盈利的情况下，[SEP]
#
# 原始文本(目标文本)
# [CLS]  路  行  业  要克  服    盲  目的、低水平的重复建设，要使  这  些从事集  成  电路的主体企业能够一步一  步  地从投资转向  运  营，在运  营  过程当中，除了  技  术要取  得  成  功  之外，[SEP]而且仅仅凭一  条    生  产线的产能，有的还实现不了现金  流  为正，在相当长时间  还  实  现  不  了  企业的  盈  利。在企业不能盈利的情况下，[SEP]
#
#
# |      120/1000000000 steps| 135198.98 tokens/s| loss   10.71| loss_mlm: 10.011| loss_sp: 0.695| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]并被中国[MASK]监会[MASK]罚[MASK][MASK]中国经营报报道，立信作为上市公司[UNK]东方精工[UNK]的2018年年报审计机构，[SEP]对其从福田汽[MASK]收购的公司计提38.48[MASK]元商[MASK]减值出具了标准无保留意见[MASK]计报告，[MASK][MASK]19日，被福田 ##鰓 车  质  疑违反审  柢  准[MASK]。继2018[MASK]10 790 ，立[MASK] ##鍋 上市[MASK]司[UNK]大智慧[UNK]（维权）案终审[SEP]
#
# 填入预测词后的文本：
# [CLS]并被中国  甌  监会 ##90罚  遒    瀑  中国经营报报道，立信作为上市公司[UNK]东方精工[UNK]的2018年年报审计机构，[SEP]对其从福田汽  檻  收购的公司计提38.48  厌  元商  劏  减值出具了标准无保留意见 exe 计报告，  氮   ##霆 19日，被福田 ##ve车  癜  疑违反审  終  准 ##汩 。继2018##58010aphojoy，立  懦    桃  上市  劏  司[UNK]大智慧[UNK]（维权）案终审[SEP]
#
# 原始文本(目标文本)
# [CLS]并被中国  证  监会  处  罚  。    据  中国经营报报道，立信作为上市公司[UNK]东方精工[UNK]的2018年年报审计机构，[SEP]对其从福田汽  车  收购的公司计提38.48  亿  元商  誉  减值出具了标准无保留意见  审  计报告，  4    月  19日，被福田  汽  车  质  疑违反审  计  准  则  。继2018  年  10  月  ，立  信    涉  上市  公  司[UNK]大智慧[UNK]（维权）案终审[SEP]
#
#
# |      125/1000000000 steps| 126145.59 tokens/s| loss   10.66| loss_mlm: 9.971| loss_sp: 0.686| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]文|[MASK]橙 ##始 品|网易科技《[MASK]℃[MASK]栏目组[UNK][MASK]是故意不来现[MASK]的。[UNK]相比去年微信[MASK]开课之夜历[MASK]性地讲了整整四个[MASK]时，[SEP]今[MASK]仍然穿着标志 ##倆 灰 ##勛 卫衣的张[MASK]龙 ##赘 却只[MASK]现在了开场vc##r中，[MASK]槽开大会、吐槽精装广告与digital户隐私间的矛盾，以及 ##任 于微信这些年的思考。[UNK]参[MASK]各种会[SEP]
#
# 填入预测词后的文本：
# [CLS]文| ##觀 橙 doc 品|网易科技《image℃  嘭  栏目组[UNK]  喟  是故意不来现  人  的。[UNK]相比去年微信 105 开课之夜历  遒  性地讲了整整四个 ##牧 时，[SEP]今##580仍然穿着标志 ##喽 灰  禽  卫衣的张 ##汩 龙 ##凍 却只  艋  现在了开场vc##r中，  勺  槽开大会、吐槽精装广告与 ##妣 户隐私间的矛盾，以及 ##ルフ于微信这些年的思考。[UNK]参  捎  各种会[SEP]
#
# 原始文本(目标文本)
# [CLS]文|  一  橙  出  品|网易科技《  态  ℃  》  栏目组[UNK]  我  是故意不来现  场  的。[UNK]相比去年微信  公  开课之夜历  史  性地讲了整整四个  小  时，[SEP]今  年  仍然穿着标志  性  灰  色  卫衣的张  小  龙  ，  却只  出  现在了开场vc##r中，  吐  槽开大会、吐槽精装广告与  用  户隐私间的矛盾，以及  关  于微信这些年的思考。[UNK]参  加  各种会[SEP]
# |      130/1000000000 steps| 127511.05 tokens/s| loss   10.70| loss_mlm: 10.016| loss_sp: 0.686| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]中国航天[MASK]技集 ##颜 微信公众号1月15日10  时  53[MASK]，我国[MASK]太原卫星发射  中  心使用长征二号丁运[MASK][MASK]箭，成功将吉林一号宽幅01 ##價 和3颗小卫[MASK]送入预[MASK]轨[MASK]，发射任务取得[MASK]满[MASK]功。长征二号丁运载火箭点火升空。[SEP]本[MASK]图片[MASK]国航天  科  技集团微信公众号长征二号丁[MASK][MASK]火箭奔向苍穹。[SEP]
#
# 填入预测词后的文本：
# [CLS]中国航天##ちゃん技集 ##掖 微信公众号1月15日10 ##娲 53  逶  ，我国  瀑  太原卫星发射  資  心使用长征二号丁运  ╚    遒  箭，成功将吉林一号宽幅01 ##筱 和3颗小卫  懦  送入预 ##牺 轨 ##牦 ，发射任务取得 ##牦 满 ##糯 功。长征二号丁运载火箭点火升空。[SEP]本 ##愫 图片  咎  国航天  轍  技集团微信公众号长征二号丁  gl  ##这 火箭奔向苍穹。[SEP]
#
# 原始文本(目标文本)
# [CLS]中国航天  科  技集  团  微信公众号1月15日10  时  53  分  ，我国  在  太原卫星发射  中  心使用长征二号丁运  载    火  箭，成功将吉林一号宽幅01  星  和3颗小卫  星  送入预  定  轨  道  ，发射任务取得  圆  满  成  功。长征二号丁运载火箭点火升空。[SEP]本  文  图片  中  国航天  科  技集团微信公众号长征二号丁  运    载  火箭奔向苍穹。[SEP]
#
#
# |      135/1000000000 steps| 138850.79 tokens/s| loss   10.68| loss_mlm: 9.984| loss_sp: 0.698| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]其向新京报记[MASK]表示，自己[UNK]不只是自然表达，有更深层的含义[MASK]，[SEP][MASK]向[MASK][MASK]推荐一篇相关论文作为参考。专家：需要进[MASK]步[MASK]查相关责任人教育专家熊丙奇[MASK]新京[MASK]记[MASK]表示，引发[MASK]界争议的论文能够[MASK]常发表出[MASK]，[MASK]要进[MASK]步[MASK]查相[MASK][MASK]任人。其表示，文章的主题是赞美  导  师，即[SEP]
#
# 填入预测词后的文本：
# [CLS]其向新京报记 ##メ 表示，自己[UNK]不只是自然表达，有更深层的含义  ╚  ，[SEP]  資  向 ##呗   檻  推荐一篇相关论文作为参考。专家：需要进 hbl 步 ##晰 查相关责任人教育专家熊丙奇 いします新京  紜  记 esp 表示，引发  掲  界争议的论文能够 ##涂 常发表出 ##岬 ，  檻  要进 ##呗 步edward查相 ##鴿   查  任人。其表示，文章的主题是赞美##ject师，即[SEP]
#
# 原始文本(目标文本)
# [CLS]其向新京报记  者  表示，自己[UNK]不只是自然表达，有更深层的含义[UNK]，[SEP]  并  向  记    者  推荐一篇相关论文作为参考。专家：需要进  一  步  追  查相关责任人教育专家熊丙奇  对  新京  报  记  者  表示，引发  外  界争议的论文能够  正  常发表出  来  ，  需  要进  一  步  追  查相  关    责  任人。其表示，文章的主题是赞美  导  师，即[SEP]
#
#
# |      140/1000000000 steps| 128701.85 tokens/s| loss   10.70| loss_mlm: 9.987| loss_sp: 0.713| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]过60%来自自[MASK][MASK]量。秋季正价课学员97万，实[MASK]400%+年同比增长。正在进行的[MASK][MASK]学[MASK]，正价[MASK]学员招[MASK]已稳定超[MASK][MASK]万。在这篇题为《写在作  侥  帮六[MASK][UNK][UNK]因为有你，[MASK]  来  可期》的公开信中，  抉  建[MASK]还宣布了在今年  韆  月1日，作业帮[MASK]课正式更名作业  芯  直播课，[SEP]就是学习效果。[SEP]
#
# 填入预测词后的文本：
# [CLS]过60%来自自  咽    屏  量。秋季正价课学员97万，实 skip400%+年同比增长。正在进行的  龕   ##勞 学  遒  ，正价  咎  学员招 105 已稳定超  荆   ##钩 万。在这篇题为《写在作##gen帮六 ##ᅭ [UNK][UNK]因为有你，  屏   1941可期》的公开信中，##ies建 274 还宣布了在今年  ｉ  月1日，作业帮 ##佶 课正式更名作业 ##メ 直播课，[SEP]就是学习效果。[SEP]
#
# 原始文本(目标文本)
# [CLS]过60%来自自  有    流  量。秋季正价课学员97万，实  现  400%+年同比增长。正在进行的  寒    假  学  期  ，正价  课  学员招  生  已稳定超  过    百  万。在这篇题为《写在作  业  帮六  年  [UNK][UNK]因为有你，  未    来  可期》的公开信中，  侯  建  彬  还宣布了在今年  1  月1日，作业帮  一  课正式更名作业  帮  直播课，[SEP]就是学习效果。[SEP]
#
#
# |      145/1000000000 steps| 135005.93 tokens/s| loss   10.66| loss_mlm: 9.958| loss_sp: 0.699| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]说，她们的母女关系[MASK][MASK]不可能回到从[MASK]  ，  她绝不会原谅[MASK]亲。最近，沃尔[MASK]有了新[MASK]伴侣，并怀了身孕。她说，她 vfm 像患[MASK][MASK]心病，再不敢相信任  何  人了。而她的[MASK]亲至今仍坚持认为，[SEP]原标题：新婚不[MASK][MASK]亲[UNK]抢[MASK][MASK]女儿丈夫还生了娃5年后再婚据[MASK]国《每日邮[MASK]》1月 ##cp日报道，[SEP]
#
# 填入预测词后的文本：
# [CLS]说，她们的母女关系 ##赃  ##汩 不可能回到从  ∀   ##仟 她绝不会原谅  喟  亲。最近，沃尔 105 有了新  荧  伴侣，并怀了身孕。她说，她 ##瀑 像患 ##貨   r9 心病，再不敢相信任  呦  人了。而她的  帐  亲至今仍坚持认为，[SEP]原标题：新婚不 mod   帐  亲[UNK]抢 ##羟  429 女儿丈夫还生了娃5年后再婚据 ##呗 国《每日邮 ##紜 》1月 ##麾 日报道，[SEP]
#
# 原始文本(目标文本)
# [CLS]说，她们的母女关系  再    也  不可能回到从  前    ，  她绝不会原谅  母  亲。最近，沃尔  又  有了新  的  伴侣，并怀了身孕。她说，她  好  像患  了    疑  心病，再不敢相信任  何  人了。而她的  母  亲至今仍坚持认为，[SEP]原标题：新婚不  久    母  亲[UNK]抢  走  [UNK]女儿丈夫还生了娃5年后再婚据  英  国《每日邮  报  》1月  19 日报道，[SEP]
#
#
# |      150/1000000000 steps| 139392.23 tokens/s| loss   10.70| loss_mlm: 10.013| loss_sp: 0.689| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS][MASK]出 ##腦 属包装设  计  ，持续打造贴近时代的国[MASK][MASK]牌形象。基础白奶价格底仍有向上弹性。实际调研可[MASK]，[SEP]线上[MASK][MASK]无论京东或天猫旗舰店数[MASK]显示[MASK]品牌[MASK]奶的销售[MASK]续处在  热  销品类第一集团，16盒标准款定价48元，24[MASK]礼[MASK]装定价70[MASK]，[SEP]
#
# 填入预测词后的文本：
# [CLS] ##佶 出  卓  属包装设 ##咪 ，持续打造贴近时代的国 ##聯   嘭  牌形象。基础白奶价格底仍有向上弹性。实际调研可  遒  ，[SEP]线上  檻    觊  无论京东或天猫旗舰店数 ##りの显示  结  品牌  ゅ  奶的销售  帐  续处在##ject销品类第一集团，16盒标准款定价48元，24  濯  礼  喟  装定价70##cept，[SEP]
#
# 原始文本(目标文本)
# [CLS]  推  出  专  属包装设  计  ，持续打造贴近时代的国  民    品  牌形象。基础白奶价格底仍有向上弹性。实际调研可  见  ，[SEP]线上  电    商  无论京东或天猫旗舰店数  据  显示  母  品牌  纯  奶的销售  持  续处在  热  销品类第一集团，16盒标准款定价48元，24  盒  礼  盒  装定价70  元  ，[SEP]
#
#
# |      155/1000000000 steps| 129376.91 tokens/s| loss   10.71| loss_mlm: 10.010| loss_sp: 0.702| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS][MASK]研讨会现场，王一方从悬棺谈起，[MASK]为悬[MASK]的[UNK]悬[UNK]既是悬挂的[UNK]悬[UNK]，又是悬案[MASK][UNK]悬[UNK]，书中的相关[MASK]究，[SEP]但陆敬[MASK]同时强  调  ，地震学是[MASK]兴[MASK][MASK]立学科，了解中国古代在地震学[MASK]的巨大成就，能使现代[MASK]究者[MASK]到启发  ，  但不应[MASK]分[MASK]大地动仪的  灵  敏性。对张衡地动仪的误[MASK][MASK][SEP]
#
# 填入预测词后的文本：
# [CLS] ##佶 研讨会现场，王一方从悬棺谈起， ##羧 为悬 ##聯 的[UNK]悬[UNK]既是悬挂的[UNK]悬[UNK]，又是悬案  人  [UNK]悬[UNK]，书中的相关  フ  究，[SEP]但陆敬  懦  同时强  崖  ，地震学是 いします兴herme 2～3 立学科，了解中国古代在地震学  蹋  的巨大成就，能使现代 ##呂 究者 ##愫 到启发 1350但不应 ##呗 分 ##拽 大地动仪的 ##餌 敏性。对张衡地动仪的误  捎  books[SEP]
#
# 原始文本(目标文本)
# [CLS]  在  研讨会现场，王一方从悬棺谈起，  认  为悬  棺  的[UNK]悬[UNK]既是悬挂的[UNK]悬[UNK]，又是悬案  的  [UNK]悬[UNK]，书中的相关  研  究，[SEP]但陆敬  严  同时强  调  ，地震学是  新  兴  的    独  立学科，了解中国古代在地震学  上  的巨大成就，能使现代  研  究者  受  到启发  ，  但不应  过  分  夸  大地动仪的  灵  敏性。对张衡地动仪的误  差    做  [SEP]
# |      160/1000000000 steps| 116869.94 tokens/s| loss   10.72| loss_mlm: 10.017| loss_sp: 0.698| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]国内很多[MASK]迷往往将05##2c[MASK][MASK]所[MASK]用的动力描[MASK]为[UNK]柴燃联合[UNK]，既为co##da##g，这种动力方式通常使用  2   coc 燃气轮机和2[MASK]柴油机，或是1台燃气[MASK]机加2台柴油机[MASK]在低[MASK]巡航时可以使用柴油动力，[SEP]而我们今天[MASK]解[MASK]的[MASK][MASK] ##钯 是上文提到的中间一档，柴  岀  [MASK]+燃气轮机的组合动力[MASK][SEP]
#
# 填入预测词后的文本：
# [CLS]国内很多 ##侶 迷往往将05##2c##mber ##憤 所 ##佶 用的动力描 1941为[UNK]柴燃联合[UNK]，既为co##da##g，这种动力方式通常使用 ##耋   漂  燃气轮机和2  帐  柴油机，或是1台燃气 ##侖 机加2台柴油机  帐  在低 ##腭 巡航时可以使用柴油动力，[SEP]而我们今天  檻  解action的  桐    喟   ##瞌 是上文提到的中间一档，柴  妾   2016+燃气轮机的组合动力  檻  [SEP]
#
# 原始文本(目标文本)
# [CLS]国内很多  军  迷往往将05##2c  /    d  所  使  用的动力描  述  为[UNK]柴燃联合[UNK]，既为co##da##g，这种动力方式通常使用  2    台  燃气轮机和2  台  柴油机，或是1台燃气  轮  机加2台柴油机  。  在低  速  巡航时可以使用柴油动力，[SEP]而我们今天  要  解  惑  的  恰    恰    就  是上文提到的中间一档，柴  油    机  +燃气轮机的组合动力  ，  [SEP]
#
#
# |      165/1000000000 steps| 131999.21 tokens/s| loss   10.67| loss_mlm: 9.987| loss_sp: 0.683| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]研究团[MASK][MASK]经在与一些不愿透露[MASK]名的制造商在进行谈判。[SEP]他们说[MASK]这些制造商可[MASK]毫[MASK]费力地将新型化学物质[MASK]制[MASK]方法整合到现有[MASK]锂离[MASK]生产设施[MASK]。[SEP]
#
# 填入预测词后的文本：
# [CLS]研究团 ##聴  ##勞 经在与一些不愿透露 ##佶 名的制造商在进行谈判。[SEP]他们说  檻  这些制造商可  帐  毫 ##閹 费力地将新型化学物质  觊  制 ##囤 方法整合到现有  癒  锂离##580生产设施 ##涂 。[SEP]
#
# 原始文本(目标文本)
# [CLS]研究团  队    已  经在与一些不愿透露  姓  名的制造商在进行谈判。[SEP]他们说  ，  这些制造商可  以  毫  不  费力地将新型化学物质  和  制  造  方法整合到现有  的  锂离  子  生产设施  中  。[SEP]
#
#
# |      170/1000000000 steps| 130879.78 tokens/s| loss   10.67| loss_mlm: 9.979| loss_sp: 0.688| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]依旧青[MASK]可爱，那么今天就跟着小编  一  [MASK]来看一看张含韵的时尚穿搭吧。[MASK]久不  见  的[MASK]含韵近日再次现身，十分日常简单的装扮，但是 ##fu人一眼就能认[MASK][MASK]，依旧那么的[MASK]春 mlb 爱 ##皑 草绿色的针织衫 ##嘆 配浅蓝色的[MASK]仔半裙十[MASK]的具有活力。[SEP]但终究没能再次火[MASK][MASK][MASK]不过这么多年过去了[MASK][SEP]
#
# 填入预测词后的文本：
# [CLS]依旧青tokichoi可爱，那么今天就跟着小编 ##蟻  ##鏗 来看一看张含韵的时尚穿搭吧。  旖  久不 ##緊 的  人  含韵近日再次现身，十分日常简单的装扮，但是 ##鈎 人一眼就能认  藿   ##牦 ，依旧那么的 ##麻 春  啼  爱 ##繡 草绿色的针织衫 ##˚ 配浅蓝色的 ##簧 仔半裙十 ##恣 的具有活力。[SEP]但终究没能再次火 ##淩  2016##key不过这么多年过去了  檻  [SEP]
#
# 原始文本(目标文本)
# [CLS]依旧青  春  可爱，那么今天就跟着小编  一    起  来看一看张含韵的时尚穿搭吧。  许  久不  见  的  张  含韵近日再次现身，十分日常简单的装扮，但是  让  人一眼就能认  出    来  ，依旧那么的  青  春  可  爱  。  草绿色的针织衫  搭  配浅蓝色的  牛  仔半裙十  分  的具有活力。[SEP]但终究没能再次火  起    来    ，  不过这么多年过去了  ，  [SEP]
#
#
# |      175/1000000000 steps| 113125.63 tokens/s| loss   10.66| loss_mlm: 9.970| loss_sp: 0.691| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]《指导意[MASK]》明确了进一步支持和[MASK]励事业单位科研人员创新创[MASK]的具体政策措[MASK]：  一  是支[MASK]和鼓励科研  人  [MASK]兼职创新、在职创办[MASK]业，[SEP]原标题：人社部：鼓励事业单位科[MASK]人员在职[MASK][MASK]岗创业为进一步激发高校、科[MASK]院所等[MASK]业单位[MASK][MASK]人员科技创新活力和[MASK]技[MASK]果转化创业热情[MASK][SEP]
#
# 填入预测词后的文本：
# [CLS]《指导意 ##勞 》明确了进一步支持和curve励事业单位科研人员创新创tokichoi的具体政策措 ##嚨 ：  唯  是支beauty和鼓励科研 ##慶  105 兼职创新、在职创办  屏  业，[SEP]原标题：人社部：鼓励事业单位科 ##呗 人员在职  掲  ##don岗创业为进一步激发高校、科 ##りの院所等 ##呗 业单位 ##呗  ##汩 人员科技创新活力和##580技 ##委 果转化创业热情  檻  [SEP]
#
# 原始文本(目标文本)
# [CLS]《指导意  见  》明确了进一步支持和  鼓  励事业单位科研人员创新创  业  的具体政策措  施  ：  一  是支  持  和鼓励科研  人    员  兼职创新、在职创办  企  业，[SEP]原标题：人社部：鼓励事业单位科  研  人员在职  或    离  岗创业为进一步激发高校、科  研  院所等  事  业单位  科    研  人员科技创新活力和  科  技  成  果转化创业热情  ，  [SEP]
#
#
# |      180/1000000000 steps| 125555.11 tokens/s| loss   10.69| loss_mlm: 9.980| loss_sp: 0.708| acc_mlm: 0.000| acc_sp: 0.000
# 输入的处理后文本：
# [CLS]细看她[MASK]款珠宝的两种色[MASK]的呈现首先就叫人感到超有[MASK]目[MASK]，  而  [MASK]身满是钻石的设计选择[MASK]是完美显露出刘亦菲本身的一[MASK]女星地位[MASK]。[SEP]在很多人[MASK]固有思想中一  定  会觉得女[MASK]出[MASK]大型[MASK]动必须选礼裙，可你们看像[MASK][MASK]菲[MASK]种穿[MASK]西装后的形象  其  实也是很适合那种自带隆重感的活动[SEP]
#
# 填入预测词后的文本：
# [CLS]细看她tokichoi款珠宝的两种色 ##袞 的呈现首先就叫人感到超有 ##牦 目 ##佶 ，  煞   ##浄 身满是钻石的设计选择 ##牦 是完美显露出刘亦菲本身的一  懦  女星地位  諗  。[SEP]在很多人 ##委 固有思想中一 text会觉得女 ##繡 出 ##呗 大型 ##с 动必须选礼裙，可你们看像 ##籁   檻  菲  鸥  种穿 ##霆 西装后的形象  谦  实也是很适合那种自带隆重感的活动[SEP]
#
# 原始文本(目标文本)
# [CLS]细看她  这  款珠宝的两种色  系  的呈现首先就叫人感到超有  夺  目  感  ，  而    本  身满是钻石的设计选择  更  是完美显露出刘亦菲本身的一  线  女星地位  呢  。[SEP]在很多人  的  固有思想中一  定  会觉得女  星  出  席  大型  活  动必须选礼裙，可你们看像  刘    亦  菲  这  种穿  起  西装后的形象  其  实也是很适合那种自带隆重感的活动[SEP]
#
#
# |      185/1000000000 steps| 134241.33 tokens/s| loss   10.67| loss_mlm: 9.979| loss_sp: 0.690| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]相同。角色不再局限于小鲜[MASK]，[MASK]这几[MASK]越[MASK][MASK]能[MASK]驭不同的题材，像[MASK][MASK]根正苗红帅而不娘的长相，事实[MASK][MASK][MASK]正剧中更受 ##诺 迎。毕业于军艺且有过入伍[MASK]历的杨洋有一副端正的好[MASK]板，加[MASK]其颜值，对各种类型[MASK]服装都驾驭自如，[SEP]而他[MASK]有的穿衣风格[MASK]十分彰显自己[MASK]青春活力，[SEP]
#
# 填入预测词后的文本：
# [CLS]相同。角色不再局限于小鲜image， ##佶 这几  ∀  越 ##た  ##侶 能 ##佶 驭不同的题材，像 ##缄   怨  根正苗红帅而不娘的长相，事实 105  ##荽  ##佶 正剧中更受 ##烂 迎。毕业于军艺且有过入伍 ##飙 历的杨洋有一副端正的好  峦  板，加 ##とは其颜值，对各种类型 105 服装都驾驭自如，[SEP]而他 ##cn有的穿衣风格  檻  十分彰显自己 ##委 青春活力，[SEP]
#
# 原始文本(目标文本)
# [CLS]相同。角色不再局限于小鲜  肉  ，  他  这几  年  越  来    越  能  驾  驭不同的题材，像  这    样  根正苗红帅而不娘的长相，事实  证    明    在  正剧中更受  欢  迎。毕业于军艺且有过入伍  经  历的杨洋有一副端正的好  身  板，加  上  其颜值，对各种类型  的  服装都驾驭自如，[SEP]而他  特  有的穿衣风格  也  十分彰显自己  的  青春活力，[SEP]
# |      190/1000000000 steps| 139171.58 tokens/s| loss   10.65| loss_mlm: 9.945| loss_sp: 0.708| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]至[MASK]近一年共[MASK]20余万元。调查还发现[MASK][SEP]该[MASK][MASK]公司注册地在南京市栖霞区，因  经  营不[MASK]已经倒闭，在高淳租赁的 arm 房更是早已[UNK]人去楼空[UNK]。然而，司法[UNK]讨[MASK][MASK]也很  淹  难。为寻找企业负责人  ，  周忠强通过街道、司法所[MASK]多方了[MASK]、查找，最终联系到  该  服饰公司 ##19定[MASK][MASK]人[MASK]某。周[SEP]
#
# 填入预测词后的文本：
# [CLS]至 matt近一年共 have20余万元。调查还发现 ##午 [SEP]该  ├   ##籁 公司注册地在南京市栖霞区，因 ##槿 营不  弧  已经倒闭，在高淳租赁的 ##zz房更是早已[UNK]人去楼空[UNK]。然而，司法[UNK]讨 ##婴  ##霆 也很  孛  难。为寻找企业负责人##iti周忠强通过街道、司法所  圜  多方了  帐  、查找，最终联系到 ##蜀 服饰公司  終  定 ##晰  ##委 人 ##赐 某。周[SEP]
#
# 原始文本(目标文本)
# [CLS]至  今  近一年共  欠  20余万元。调查还发现  ，  [SEP]该  服    饰  公司注册地在南京市栖霞区，因  经  营不  善  已经倒闭，在高淳租赁的  厂  房更是早已[UNK]人去楼空[UNK]。然而，司法[UNK]讨  薪  [UNK]也很  艰  难。为寻找企业负责人  ，  周忠强通过街道、司法所  等  多方了  解  、查找，最终联系到  该  服饰公司  法  定  代    表  人  高  某。周[SEP]
#
#
# |      195/1000000000 steps| 140421.16 tokens/s| loss   10.68| loss_mlm: 9.978| loss_sp: 0.697| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]仅2019年12月[MASK]头部厂商的5g手机[MASK]布就一个挨[MASK]一[MASK]，[SEP]显示出对2020[MASK]的蓄力。中国信通[MASK]统[MASK]显示，在5g商用开启[MASK]，国内市场的手机[MASK]货也在[MASK]速增长。1-10  月  5g手  酿  [MASK]出货328.1万部[MASK]而[MASK]-12月已共有137##6.9万 ##山 5g手机出货，占总市场体量的3.5[MASK]。但也正  因  为5g时代[MASK][SEP]
#
# 填入预测词后的文本：
# [CLS]仅2019年12月 ##us头部厂商的5g手机  弈  布就一个挨  遒  一 いします，[SEP]显示出对2020  檻  的蓄力。中国信通  癒  统  頑  显示，在5g商用开启  檻  ，国内市场的手机  艹  货也在  劏  速增长。1-10 3kg 5g手 ##cn ##りの出货328.1万部  咙  而 ##淩 -12月已共有137##6.9万  終  5g手机出货，占总市场体量的3.5  v1 。但也正 ##夺 为5g时代  檻  [SEP]
#
# 原始文本(目标文本)
# [CLS]仅2019年12月  ，  头部厂商的5g手机  发  布就一个挨  着  一  个  ，[SEP]显示出对2020  年  的蓄力。中国信通  院  统  计  显示，在5g商用开启  后  ，国内市场的手机  出  货也在  快  速增长。1-10  月  5g手  机    总  出货328.1万部  ，  而  1  -12月已共有137##6.9万  部  5g手机出货，占总市场体量的3.5  %  。但也正  因  为5g时代  ，  [SEP]
#
#
# |      200/1000000000 steps| 134372.57 tokens/s| loss   10.66| loss_mlm: 9.959| loss_sp: 0.702| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]新型冠状病毒感染 ##蠣 [MASK]控[MASK]王[MASK]丹表示，一是对疑似感染者进行隔离，尽快确诊，[MASK]密切接触[MASK]进行医学观察[MASK][MASK][MASK]内大[MASK]分确诊病例的[MASK]同[MASK]点 ##ll到  过  武汉。同[MASK]，他也建议到过武汉的人尽量减少外  出  ，如果有疑似症状[MASK][SEP]应该尽快就医。并且在就医[MASK]应该告诉医生[MASK]近期到过武汉。[SEP]
#
# 填入预测词后的文本：
# [CLS]新型冠状病毒感染 ##ة  ##赃 控##mber王  遒  丹表示，一是对疑似感染者进行隔离，尽快确诊， ##莠 密切接触  绣  进行医学观察 ##簧  ##旅  ##侶 内大 280 分确诊病例的 ##簧 同 ##憎 点  炭  到 ##ku武汉。同  炁  ，他也建议到过武汉的人尽量减少外  萼  ，如果有疑似症状 ##ᅭ [SEP]应该尽快就医。并且在就医 ##呗 应该告诉医生 ##这 近期到过武汉。[SEP]
#
# 原始文本(目标文本)
# [CLS]新型冠状病毒感染  的    防  控  ，  王  月  丹表示，一是对疑似感染者进行隔离，尽快确诊，  对  密切接触  者  进行医学观察  。    国    外  内大  部  分确诊病例的  共  同  特  点  是  到  过  武汉。同  时  ，他也建议到过武汉的人尽量减少外  出  ，如果有疑似症状  ，  [SEP]应该尽快就医。并且在就医  时  应该告诉医生  ，  近期到过武汉。[SEP]
#
#
# |      205/1000000000 steps| 136255.06 tokens/s| loss   10.65| loss_mlm: 9.970| loss_sp: 0.680| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]之年，但是长期的保[MASK]和时尚穿搭造就她一[MASK]能拥有[MASK]颗年轻[MASK]心，比如[MASK]她[MASK]次穿一件ch##lo##e鼠年限量[MASK]列三鼠迎春白色t恤显得可爱，甚至右手还[MASK]出一个小[MASK]型，既搞怪又减龄[MASK][MASK]常年轻 ##煊 [MASK]心[MASK]穿mo##sch##ino[SEP]mi##ck##eyra##t红  衣  显得[MASK]气而林[MASK][MASK]身上则套[MASK]是mo##sch##ino表情搞怪的mi##ck##ey[SEP]
#
# 填入预测词后的文本：
# [CLS]之年，但是长期的保 ##赃 和时尚穿搭造就她一 ##聯 能拥有 ##勢 颗年轻  桓  心，比如 ##ね 她 ##メ 次穿一件ch##lo##e鼠年限量beauty列三鼠迎春白色t恤显得可爱，甚至右手还  溝  出一个小 ##敲 型，既搞怪又减龄 ##メ  ##禾 常年轻  診    溝  心  甌  穿mo##sch##ino[SEP]mi##ck##eyra##t红 ##耋 显得 ##呗 气而林 ##晰  llc 身上则套  掲  是mo##sch##ino表情搞怪的mi##ck##ey[SEP]
#
# 原始文本(目标文本)
# [CLS]之年，但是长期的保  养  和时尚穿搭造就她一  直  能拥有  一  颗年轻  的  心，比如  说  她  此  次穿一件ch##lo##e鼠年限量  系  列三鼠迎春白色t恤显得可爱，甚至右手还  摆  出一个小  造  型，既搞怪又减龄  ，    非  常年轻  。    林  心  如  穿mo##sch##ino[SEP]mi##ck##eyra##t红  衣  显得  喜  气而林  心    如  身上则套  上  是mo##sch##ino表情搞怪的mi##ck##ey[SEP]
#
#
# |      210/1000000000 steps| 138256.99 tokens/s| loss   10.63| loss_mlm: 9.936| loss_sp: 0.690| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]让慵懒[MASK]更强。蕾丝裙上的纹路大而[MASK]乱，破坏了层次感，与[MASK]按常理[MASK][MASK]的  红  色毛衣放在一起，[SEP]打破了[MASK]色的统治，[MASK]变得很小  清  新了。毛衣[MASK]意扎入裙[MASK]，[SEP]
#
# 填入预测词后的文本：
# [CLS]让慵懒tokichoi更强。蕾丝裙上的纹路大而  喟  乱，破坏了层次感，与 ##範 按常理 ##缄  ##] 的  ﹑  色毛衣放在一起，[SEP]打破了 ##炖 色的统治， ##坝 变得很小  愕  新了。毛衣  劏  意扎入裙  檻  ，[SEP]
#
# 原始文本(目标文本)
# [CLS]让慵懒  感  更强。蕾丝裙上的纹路大而  凌  乱，破坏了层次感，与  不  按常理  出    牌  的  红  色毛衣放在一起，[SEP]打破了  红  色的统治，  就  变得很小  清  新了。毛衣  随  意扎入裙  子  ，[SEP]
#
#
# |      215/1000000000 steps| 134813.12 tokens/s| loss   10.68| loss_mlm: 9.981| loss_sp: 0.696| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS][MASK]当两者[MASK]遇，[SEP]国际医学界新兴[MASK]细胞与免疫抗癌疗法[MASK]  很   1932获得期望的疗效。[SEP]
#
# 填入预测词后的文本：
# [CLS] ##佶 当两者  啜  遇，[SEP]国际医学界新兴 いします细胞与免疫抗癌疗法  癒   ##纪   掲  获得期望的疗效。[SEP]
#
# 原始文本(目标文本)
# [CLS]  但  当两者  相  遇，[SEP]国际医学界新兴  的  细胞与免疫抗癌疗法  也    很    难  获得期望的疗效。[SEP]
#
#
# |      220/1000000000 steps| 136388.33 tokens/s| loss   10.66| loss_mlm: 9.972| loss_sp: 0.688| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]  声  明：文字原创，图片来自  网  络。[SEP]如有侵[MASK][MASK][MASK]联系我们删除，谢谢。[SEP]
#
# 填入预测词后的文本：
# [CLS] ##栈 明：文字原创，图片来自 372 络。[SEP]如有侵##iti  劏   ##籁 联系我们删除，谢谢。[SEP]
#
# 原始文本(目标文本)
# [CLS]  声  明：文字原创，图片来自  网  络。[SEP]如有侵  权    ，    请  联系我们删除，谢谢。[SEP]
#
#
# |      225/1000000000 steps| 138228.18 tokens/s| loss   10.64| loss_mlm: 9.947| loss_sp: 0.691| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]状态，但是却越来越[MASK]女人味，[MASK][MASK]道这[MASK]的李沁你们  是  [MASK]喜欢呢？除了李沁的  神  仙颜[MASK]之外，这次她身  上  的[MASK]款[MASK][UNK]也引[MASK]了网友[MASK]的关注。全身都选择了银灰色的小亮片，[SEP]给人一种将镜子[MASK]在[MASK]上的[MASK]视感，使得镜头前[MASK][MASK]沁美的更加出众。而高开叉的裙摆与高跟鞋搭配[MASK]一起，[SEP]
#
# 填入预测词后的文本：
# [CLS]状态，但是却越来越 ##赃 女人味， ##佶  ##餡 道这  弈  的李沁你们200mm  遒  喜欢呢？除了李沁的 ##墀 仙颜 ##佶 之外，这次她身 ##訕 的  ф  款  ╚  [UNK]也引 ##佶 了网友financial的关注。全身都选择了银灰色的小亮片，[SEP]给人一种将镜子  めた 在  牟  上的 ##涂 视感，使得镜头前  辅   ##呗 沁美的更加出众。而高开叉的裙摆与高跟鞋搭配 ##赐 一起，[SEP]
#
# 原始文本(目标文本)
# [CLS]状态，但是却越来越  有  女人味，  不    知  道这  次  的李沁你们  是    否  喜欢呢？除了李沁的  神  仙颜  值  之外，这次她身  上  的  这  款[UNK][UNK]也引  起  了网友  们  的关注。全身都选择了银灰色的小亮片，[SEP]给人一种将镜子  穿  在  身  上的  既  视感，使得镜头前  的    李  沁美的更加出众。而高开叉的裙摆与高跟鞋搭配  在  一起，[SEP]
# |      230/1000000000 steps| 137012.90 tokens/s| loss   10.68| loss_mlm: 9.988| loss_sp: 0.695| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS][MASK]人的弟弟有精神方面的问题，[MASK]间突然  旧  病复发并伴有其他并发症，[SEP]2019年11月26日[MASK]晨5点多[MASK]北京[MASK]报警服务台的[UNK]121##10[UNK]短信报[MASK]平[MASK]（[MASK][MASK]是为听力[MASK]  言  障碍者或在现场环境  不  便电话报警等特殊情况下[MASK][MASK]使用）上出现[MASK]条[MASK]息，[UNK]自己听到客厅[MASK]异响，怀[MASK]家中进人又不敢[SEP]
#
# 填入预测词后的文本：
# [CLS] ##佶 人的弟弟有精神方面的问题， ##佶 间突然  卑  病复发并伴有其他并发症，[SEP]2019年11月26日 ##sm晨5点多 ##霆 北京  環  报警服务台的[UNK]121##10[UNK]短信报  艹  平 ##呗 （ ##媧   结  是为听力 いしますlouis障碍者或在现场环境  瑛  便电话报警等特殊情况下  喟   ##霆 使用）上出现 ##峒 条##580息，[UNK]自己听到客厅##580异响，怀  掲  家中进人又不敢[SEP]
#
# 原始文本(目标文本)
# [CLS]  老  人的弟弟有精神方面的问题，  夜  间突然  旧  病复发并伴有其他并发症，[SEP]2019年11月26日  凌  晨5点多  ，  北京 110 报警服务台的[UNK]121##10[UNK]短信报  警  平  台  （  主    要  是为听力  语    言  障碍者或在现场环境  不  便电话报警等特殊情况下  求    助  使用）上出现  一  条  信  息，[UNK]自己听到客厅  有  异响，怀  疑  家中进人又不敢[SEP]
#
#
# |      235/1000000000 steps| 136011.06 tokens/s| loss   10.64| loss_mlm: 9.950| loss_sp: 0.688| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]应[MASK]持至少两名董事候[MASK][MASK]为格臻投资认可的人士[UNK]的安排，该项安排[MASK]出于保持[MASK]市公司管理层稳定连续之目的，旨在推[MASK]  蚱  [MASK][MASK]司持续发展；[SEP]相[MASK]安排[MASK]珠海毓秀董事会[UNK]三[MASK]鼎立[UNK]的[MASK]置并[MASK]冲突[MASK]且也不能认为在珠[MASK]明骏行使作为[MASK]市公司股东或相关权[MASK]所享有[MASK]权利方面，[SEP]
#
# 填入预测词后的文本：
# [CLS]应  雀  持至少两名董事候international ##汩 为格臻投资认可的人士[UNK]的安排，该项安排  資  出于保持 105 市公司管理层稳定连续之目的，旨在推  懦    以   ##侶  ##佶 司持续发展；[SEP]相 ##繡 安排  檻  珠海毓秀董事会[UNK]三  ゅ  鼎立[UNK]的  ├  置并 ##勢 冲突  魇  且也不能认为在珠  晞  明骏行使作为 ##cn市公司股东或相关权 いします所享有 ##委 权利方面，[SEP]
#
# 原始文本(目标文本)
# [CLS]应  保  持至少两名董事候  选    人  为格臻投资认可的人士[UNK]的安排，该项安排  系  出于保持  上  市公司管理层稳定连续之目的，旨在推  动    上    市    公  司持续发展；[SEP]相  关  安排  与  珠海毓秀董事会[UNK]三  足  鼎立[UNK]的  设  置并  无  冲突  ，  且也不能认为在珠  海  明骏行使作为  上  市公司股东或相关权  益  所享有  的  权利方面，[SEP]
#
#
# |      240/1000000000 steps| 128499.50 tokens/s| loss   10.63| loss_mlm: 9.933| loss_sp: 0.696| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]榜单的[MASK]三位是微软集团创始人[MASK]尔·盖茨，财富[MASK]额为110##6亿美元；[SEP]第  四    、  五位分别是[UNK][MASK]神[UNK]沃伦[MASK]巴菲特（90##6亿美元[MASK]和[MASK][MASK]创始人马克·扎克伯 ##瑕 （82##2亿美  鏡  ）。[SEP]
#
# 填入预测词后的文本：
# [CLS]榜单的 ##霆 三位是微软集团创始人 ##敲 尔·盖茨，财富 ##舜 额为110##6亿美元；[SEP]第 ##oc  鹵  五位分别是[UNK]  頑  神[UNK]沃伦  環  巴菲特（90##6亿美元  檻  和financial  尹  创始人马克·扎克伯  濯  （82##2亿美  淒  ）。[SEP]
#
# 原始文本(目标文本)
# [CLS]榜单的  第  三位是微软集团创始人  比  尔·盖茨，财富  总  额为110##6亿美元；[SEP]第  四    、  五位分别是[UNK]  股  神[UNK]沃伦  ·  巴菲特（90##6亿美元  ）  和  脸    书  创始人马克·扎克伯  格  （82##2亿美  元  ）。[SEP]
#
#
# |      245/1000000000 steps| 142638.17 tokens/s| loss   10.66| loss_mlm: 9.968| loss_sp: 0.687| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]然后用夸 ##le的语气告诉大家  揩  赴约前男友婚礼要这样穿，[SEP][UNK]衰  浬  主妇[UNK]变身年轻俏夫人一定要遵[MASK]  这  些秘诀[UNK][UNK]在那个国内还找不到几[MASK]一线[MASK]牌的年代，许多人只能通过[MASK]视或 ##孑 [MASK]志来了解[MASK]时尚[UNK][MASK]信息不[MASK]称可能确[MASK]让[MASK]些人掌握了所谓[MASK][UNK]时尚话语##board[MASK]，并且得到了[MASK]群忠实[SEP]
#
# 填入预测词后的文本：
# [CLS]然后用夸##cky的语气告诉大家 ##浄 赴约前男友婚礼要这样穿，[SEP][UNK]衰  檻  主妇[UNK]变身年轻俏夫人一定要遵  咎   287 些秘诀[UNK][UNK]在那个国内还找不到几  籲  一线  撥  牌的年代，许多人只能通过##580视或 ##鴿  ##呗 志来了解 ##馁 时尚[UNK]ios11信息不 ##凛 称可能确 ##▎ 让 ##呗 些人掌握了所谓  捎  [UNK]时尚话语  逼    邰  ，并且得到了  菖  群忠实[SEP]
#
# 原始文本(目标文本)
# [CLS]然后用夸  张  的语气告诉大家  ：  赴约前男友婚礼要这样穿，[SEP][UNK]衰  老  主妇[UNK]变身年轻俏夫人一定要遵  从    这  些秘诀[UNK][UNK]在那个国内还找不到几  个  一线  大  牌的年代，许多人只能通过  电  视或  者    杂  志来了解[UNK]时尚[UNK]  ，  信息不  对  称可能确  实  让  一  些人掌握了所谓  的  [UNK]时尚话语  权  [UNK]，并且得到了  一  群忠实[SEP]
#
#
# |      250/1000000000 steps| 151006.20 tokens/s| loss   10.68| loss_mlm: 9.987| loss_sp: 0.697| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]所占比重  最  高。然后依次为礼物费、祭祀费、旅行费和交通[MASK]。在春节连休计划方面，[SEP][MASK]行了 132 年[MASK][MASK]计划问卷调查。结果显示[MASK]韩国上班族预[MASK]今年春节开支将[MASK]50.2[MASK][MASK]元[MASK]约合  人  民币[MASK]##1[MASK]），相较前一年的45.8万韩元（约合人民币271[MASK]元）  增  加了4.4[MASK]韩元  。  据调查，[SEP]
#
# 填入预测词后的文本：
# [CLS]所占比重 220 高。然后依次为礼物费、祭祀费、旅行费和交通 ##佶 。在春节连休计划方面，[SEP]  喟  行了  瓏  年  键   ##呗 计划问卷调查。结果显示  ゅ  韩国上班族预##580今年春节开支将  帐  50.2 ##霆  exe 元  嗣  约合 ##橹 民币  めた ##1  檻  ），相较前一年的45.8万韩元（约合人民币271 com™元）  現  加了4.4  觊  韩元  es 据调查，[SEP]
#
# 原始文本(目标文本)
# [CLS]所占比重  最  高。然后依次为礼物费、祭祀费、旅行费和交通  费  。在春节连休计划方面，[SEP]  进  行了 2020年  春    节  计划问卷调查。结果显示  ，  韩国上班族预  计  今年春节开支将  达  50.2  万    韩  元  （  约合  人  民币 297 ##1  元  ），相较前一年的45.8万韩元（约合人民币271 ##0 元）  增  加了4.4  万  韩元  。  据调查，[SEP]
#
#
# |      255/1000000000 steps| 137944.05 tokens/s| loss   10.71| loss_mlm: 10.015| loss_sp: 0.692| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]登上榜首。《福布斯[MASK]最新发布的世界富豪排行榜据俄罗斯卫 890 通讯社报道，[MASK]尔诺[MASK]持的路易威登[MASK]团股票[MASK]涨了0.7 ##慚 ，[SEP]目[MASK]阿尔[MASK]的资产总额达到116##5亿美元（约合人 1080币799##1亿元 ##怠 ；而由于[MASK]马逊的[MASK]票下[MASK]了0  uv 7%，贝佐斯[MASK]115##6[MASK]美元的[MASK]富总额位列富豪榜第[MASK]位；[SEP]
#
# 填入预测词后的文本：
# [CLS]登上榜首。《福布斯 ##赃 最新发布的世界富豪排行榜据俄罗斯卫  裁  通讯社报道， ##ⓔ 尔诺  愕  持的路易威登  遒  团股票  啜  涨了0.7 ##靴 ，[SEP]目 ##りの阿尔 ##烹 的资产总额达到116##5亿美元（约合人  濯  币799##1亿元 ##篓 ；而由于  檻  马逊的 ##凛 票下 ##愫 了0##men7%，贝佐斯 exe 115##6  雄  美元的 ##淩 富总额位列富豪榜第 ##蕾 位；[SEP]
#
# 原始文本(目标文本)
# [CLS]登上榜首。《福布斯  》  最新发布的世界富豪排行榜据俄罗斯卫  星  通讯社报道，  阿  尔诺  所  持的路易威登  集  团股票  上  涨了0.7  %  ，[SEP]目  前  阿尔  诺  的资产总额达到116##5亿美元（约合人  民  币799##1亿元  ）  ；而由于  亚  马逊的  股  票下  跌  了0  .  7%，贝佐斯  以  115##6  亿  美元的  财  富总额位列富豪榜第  二  位；[SEP]
# |      260/1000000000 steps| 138426.54 tokens/s| loss   10.72| loss_mlm: 10.006| loss_sp: 0.716| acc_mlm: 0.000| acc_sp: 0.000
# 输入的处理后文本：
# [CLS]81##1型遥 hit 靶艇的艇身采用的[MASK]钢铝结构，相比当时的[MASK]壳艇更有利于部队的[MASK]##ider。[MASK]艇总长为[MASK].5米，艇身宽6[MASK]06米，吃水1.[SEP]18米[MASK]满载排水量为66吨。其动力系统采[MASK]的[MASK]四台单[MASK]功率 ##駐 88##3[MASK]瓦的[MASK]12[MASK]180型柴油机[MASK]得益于如此强劲的功率，[SEP]
#
# 填入预测词后的文本：
# [CLS]81##1型遥  獗  靶艇的艇身采用的  遒  钢铝结构，相比当时的  瀑  壳艇更有利于部队的  莹    吁  。  帐  艇总长为  啜  .5米，艇身宽6 ##楫 06米，吃水1.[SEP]18米ios11满载排水量为66吨。其动力系统采 ##繡 的 ##呗 四台单  漾  功率 ##₁ 88##3 mod 瓦的  瞰  12 ##峒 180型柴油机 ##峒 得益于如此强劲的功率，[SEP]
#
# 原始文本(目标文本)
# [CLS]81##1型遥  控  靶艇的艇身采用的  是  钢铝结构，相比当时的  木  壳艇更有利于部队的  维    护  。  该  艇总长为  25 .5米，艇身宽6  .  06米，吃水1.[SEP]18米  ，  满载排水量为66吨。其动力系统采  用  的  是  四台单  机  功率  为  88##3  千  瓦的  轻  12  -  180型柴油机  ，  得益于如此强劲的功率，[SEP]
#
#
# |      265/1000000000 steps| 133696.62 tokens/s| loss   10.67| loss_mlm: 9.986| loss_sp: 0.687| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]20家互联网公司，基本都在美国或者中国。基于信息传输协[MASK]的互联网时代，中国[MASK]全球处于  夷  领[MASK]的地[MASK]。[MASK]块  链  为什[MASK]不[MASK]这样？基[MASK]区[MASK]链的分布式[MASK]本价值传输协议，中国最高  决  策[MASK]  惕  经捕捉到了这样一个先机。而且，[SEP]区块链和互联[MASK]其实[MASK]常相似，都是对各种[MASK]系的[MASK]组，[SEP]
#
# 填入预测词后的文本：
# [CLS]20家互联网公司，基本都在美国或者中国。基于信息传输协  人  的互联网时代，中国 105 全球处于  绣  领 ##钩 的地 ##慶 。  啜  块 ##悲 为什 ##腭 不 ##ま 这样？基financial区 ##憎 链的分布式  溝  本价值传输协议，中国最高 ##侖 策  フ   ##你 经捕捉到了这样一个先机。而且，[SEP]区块链和互联  癜  其实##ash常相似，都是对各种 ##委 系的  檻  组，[SEP]
#
# 原始文本(目标文本)
# [CLS]20家互联网公司，基本都在美国或者中国。基于信息传输协  议  的互联网时代，中国  在  全球处于  很  领  先  的地  位  。  区  块  链  为什  么  不  能  这样？基  于  区  块  链的分布式  账  本价值传输协议，中国最高  决  策  层    已  经捕捉到了这样一个先机。而且，[SEP]区块链和互联  网  其实  非  常相似，都是对各种  关  系的  重  组，[SEP]
#
#
# |      270/1000000000 steps| 135560.52 tokens/s| loss   10.67| loss_mlm: 9.988| loss_sp: 0.682| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]我接到了协和医院[MASK]院长于  晓  初打来的电话。她  菟  [MASK]的中[MASK]同学，大概[MASK]其他同学找到她[MASK][SEP]从医院一回来，阿斌马上就去[MASK]房买药。药拿回[MASK]了，这时[MASK]递东西完全是不见面了。他放在地[MASK]  ，  我去取。这时候也是我最[MASK]难的时[MASK]，除了水，[MASK]他什么都咽不下去[MASK]那[MASK]  天  我都快喝成  水  中[SEP]
#
# 填入预测词后的文本：
# [CLS]我接到了协和医院 ##牺 院长于 ##汩 初打来的电话。她##type ##佶 的中  觊  同学，大概 ##蛇 其他同学找到她  喟  [SEP]从医院一回来，阿斌马上就去  懦  房买药。药拿回ios11了，这时nvidia递东西完全是不见面了。他放在地  咎   ##薛 我去取。这时候也是我最 ##愫 难的时 ##呗 ，除了水， ##cn他什么都咽不下去##key那 ##紜  ##於 我都快喝成  f3 中[SEP]
#
# 原始文本(目标文本)
# [CLS]我接到了协和医院  副  院长于  晓  初打来的电话。她  是    我  的中  学  同学，大概  是  其他同学找到她  ，  [SEP]从医院一回来，阿斌马上就去  药  房买药。药拿回  来  了，这时  候  递东西完全是不见面了。他放在地  上    ，  我去取。这时候也是我最  困  难的时  候  ，除了水，  其  他什么都咽不下去  。  那  些    天  我都快喝成  水  中[SEP]
#
#
# |      275/1000000000 steps| 141348.19 tokens/s| loss   10.69| loss_mlm: 9.992| loss_sp: 0.700| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]互联网下半场机[MASK]在[MASK]端。经[MASK]了野  蛮  生长、激[MASK]厮[MASK]的上半场，本地生  活  服[MASK]行[MASK]c端格局已定。[SEP]为维持现有用户并实[MASK]微量增长，服务[MASK]细化成为发展方向。ii  咒    摸  [MASK][MASK]（艾媒咨[MASK]）在《2019上半年中国本地生活服[MASK]行业市场监测报告》中指出，2016  至  2018年中国[MASK]线餐饮外卖、互联网[SEP]
#
# 填入预测词后的文本：
# [CLS]互联网下半场机 ##咪 在 1885端。经  遒  了野 ##墀 生长、激 105 厮 ##勢 的上半场，本地生 ##瑰 服 ##牦 行  喟  c端格局已定。[SEP]为维持现有用户并实  煊  微量增长，服务 ##呗 细化成为发展方向。ii##lock ##饵   咎  copyright（艾媒咨  掲  ）在《2019上半年中国本地生活服 ##籁 行业市场监测报告》中指出，2016  ッ  2018年中国 ##弧 线餐饮外卖、互联网[SEP]
#
# 原始文本(目标文本)
# [CLS]互联网下半场机  会  在  b  端。经  历  了野  蛮  生长、激  烈  厮  杀  的上半场，本地生  活  服  务  行  业  c端格局已定。[SEP]为维持现有用户并实  现  微量增长，服务  精  细化成为发展方向。ii##media##res##ear ##ch（艾媒咨  询  ）在《2019上半年中国本地生活服  务  行业市场监测报告》中指出，2016  至  2018年中国  在  线餐饮外卖、互联网[SEP]
#
#
# |      280/1000000000 steps| 135843.28 tokens/s| loss   10.66| loss_mlm: 9.962| loss_sp: 0.699| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]中微公司位居市值榜首1月17日，是特[MASK]生物（688##27##8）在科创板挂牌上市首日，股价报收[MASK]35.3元，较发行  头  [MASK].[SEP]24元上涨328.4[MASK]，显示市场对[MASK]这[MASK]创[MASK]型生物医药企业[MASK]追捧[MASK]度。  受  到追捧的不止  特  宝生物，当spring科创板个股集[MASK]飘红，  晶  [MASK]股份、虹软[MASK]技、睿创微纳[MASK]中[MASK][SEP]
#
# 填入预测词后的文本：
# [CLS]中微公司位居市值榜首1月17日，是特  ∀  生物（688##27##8）在科创板挂牌上市首日，股价报收 ##汩 35.3元，较发行  荆   ##腭 .[SEP]24元上涨328.4  艹  ，显示市场对 2～3 这 pad 创##firm型生物医药企业 ##汩 追捧  蹋  度。 ##欧 到追捧的不止  ღ  宝生物，当  煖  科创板个股集 ##宕 飘红，  棘   ##霆 股份、虹软  檻  技、睿创微纳 be2 中books[SEP]
#
# 原始文本(目标文本)
# [CLS]中微公司位居市值榜首1月17日，是特  宝  生物（688##27##8）在科创板挂牌上市首日，股价报收  于  35.3元，较发行  价    8  .[SEP]24元上涨328.4  %  ，显示市场对  于  这  家  创  新  型生物医药企业  的  追捧  热  度。  受  到追捧的不止  特  宝生物，当  日  科创板个股集  体  飘红，  晶    晨  股份、虹软  科  技、睿创微纳  、  中  微  [SEP]
#
#
# |      285/1000000000 steps| 128503.15 tokens/s| loss   10.72| loss_mlm: 10.030| loss_sp: 0.689| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]图：巴尔的摩[MASK]头抗议科技时代的[MASK]卫者  刮  声称，传统的宏观经济[MASK]工[MASK]不可能捕捉到智能[MASK]  机  的影响[MASK][MASK][SEP]这个小巧的设备不仅是电  话  ，还是照相机、游戏机以及[MASK]  问    巡  络[MASK]门户。他们告诉经[MASK]  谟  家：一切都在好转，除了我[MASK]衡量一切好转程度的能力。但  无  论如何算计这些[MASK]字，数字[SEP]
#
# 填入预测词后的文本：
# [CLS]图：巴尔的摩  咽  头抗议科技时代的 105 卫者  鹫  声称，传统的宏观经济  喟  工  枫  不可能捕捉到智能beauty ##瘫 的影响 ##勢  ##佶 [SEP]这个小巧的设备不仅是电##ller，还是照相机、游戏机以及  帐  ##ject ##蜀 络 ##呗 门户。他们告诉经 ##燄  ##裆 家：一切都在好转，除了我  喟  衡量一切好转程度的能力。但 ##灭 论如何算计这些  咎  字，数字[SEP]
#
# 原始文本(目标文本)
# [CLS]图：巴尔的摩  街  头抗议科技时代的  捍  卫者  们  声称，传统的宏观经济  学  工  具  不可能捕捉到智能  手    机  的影响  力    。  [SEP]这个小巧的设备不仅是电  话  ，还是照相机、游戏机以及  访    问    网  络  的  门户。他们告诉经  济    学  家：一切都在好转，除了我  们  衡量一切好转程度的能力。但  无  论如何算计这些  数  字，数字[SEP]
# |      290/1000000000 steps| 144584.31 tokens/s| loss   10.68| loss_mlm: 9.988| loss_sp: 0.694| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]优[MASK]，[MASK]有[MASK]  一  [MASK]的市场[MASK]模，[MASK]能够借助已有的销售渠道[MASK]售后服务系统，但它们在车辆设计、 ##ｓ 产以及[MASK]牌塑[MASK]等方面，依然是传统车企的套 ##ร 。与特斯拉、造 ##釧 新势力相比，产[MASK]不酷，未来感不足，吸引力不高[MASK][SEP]而且这些[MASK]辆很大部分是政府采购、出租[MASK][MASK]以及其他集团客[MASK]。[SEP]
#
# 填入预测词后的文本：
# [CLS]优 ##松 ，  溝  有 ##牦   噠    帐  的市场 ##袞 模， ##佶 能够借助已有的销售渠道  人  售后服务系统，但它们在车辆设计、 ##氙 产以及 105 牌塑  弈  等方面，依然是传统车企的套 ##喝 。与特斯拉、造  键  新势力相比，产  峦  不酷，未来感不足，吸引力不高  遒  [SEP]而且这些 ##cn辆很大部分是政府采购、出租 ##凿   檻  以及其他集团客  檻  。[SEP]
#
# 原始文本(目标文本)
# [CLS]优  势  ，  且  有  了    一    定  的市场  规  模，  也  能够借助已有的销售渠道  和  售后服务系统，但它们在车辆设计、  生  产以及  品  牌塑  造  等方面，依然是传统车企的套  路  。与特斯拉、造  车  新势力相比，产  品  不酷，未来感不足，吸引力不高  。  [SEP]而且这些  车  辆很大部分是政府采购、出租  公    司  以及其他集团客  户  。[SEP]
#
#
# |      295/1000000000 steps| 135243.57 tokens/s| loss   10.67| loss_mlm: 9.981| loss_sp: 0.693| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]但了解他想法的人士表示，[SEP]他正[MASK]划停飞该机队  ，  [MASK]在扑灭野火等紧急情况（可能还有培训）时[MASK]外使用。[MASK]部发言人则[MASK]应称，仍在评估当中，除紧急[MASK]用[MASK]，中国制造或[MASK]含中国部[MASK][MASK][MASK][MASK]机仍在[MASK]飞中。  而  美国内政部的机队 ##弑 ，有121架无人机是大[MASK][MASK]产品。大疆对此回[MASK]称：[UNK][SEP]
#
# 填入预测词后的文本：
# [CLS]但了解他想法的人士表示，[SEP]他正 いします划停飞该机队 ##縴   犒  在扑灭野火等紧急情况（可能还有培训）时  诩  外使用。 ##к 部发言人则  煊  应称，仍在评估当中，除紧急  檻  用  劏  ，中国制造或 exe 含中国部  蹋    檻    檻    po 机仍在 274 飞中。 ##殃 美国内政部的机队 ##傍 ，有121架无人机是大  劏    啃  产品。大疆对此回 ##re称：[UNK][SEP]
#
# 原始文本(目标文本)
# [CLS]但了解他想法的人士表示，[SEP]他正  计  划停飞该机队  ，    只  在扑灭野火等紧急情况（可能还有培训）时  例  外使用。  该  部发言人则  回  应称，仍在评估当中，除紧急  使  用  外  ，中国制造或  包  含中国部  件    的    无    人  机仍在  停  飞中。  而  美国内政部的机队  中  ，有121架无人机是大  疆    的  产品。大疆对此回  应  称：[UNK][SEP]
#
#
# |      300/1000000000 steps| 137326.24 tokens/s| loss   10.70| loss_mlm: 9.992| loss_sp: 0.708| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]国加州，由乔本·贝维特（joe##be[MASK]##be[MASK]##rt）创立。job##ya##via##tion的电动垂直[MASK]降飞机，飞行速度  最  高可达到[MASK]小[MASK]约320[MASK]里，一 ##鳩 充电[MASK]的[MASK]航  里  程超过240公里。job##ya##via##tion称，因[MASK]这款飞机采用了电[MASK]传model[MASK]统和多旋翼设计，[MASK][UNK]在 ##済 飞和降落时比[MASK]统飞机安静100倍，[SEP]与传统[MASK]升机相比，[SEP]
#
# 填入预测词后的文本：
# [CLS]国加州，由乔本·贝维特（joe##be ##佶 ##be ##瀰 ##rt）创立。job##ya##via##tion的电动垂直 ##蛇 降飞机，飞行速度##code高可达到  垣  小 105 约320 ##佶 里，一  ］  充电 ##憤 的 ##瀚 航  なと 程超过240公里。job##ya##via##tion称，因  フ  这款飞机采用了电[unused76]传 ##瀚   甌  统和多旋翼设计， ##浄 [UNK]在  鍊  飞和降落时比 ##勢 统飞机安静100倍，[SEP]与传统 ##委 升机相比，[SEP]
#
# 原始文本(目标文本)
# [CLS]国加州，由乔本·贝维特（joe##be ##n ##be ##vi##rt）创立。job##ya##via##tion的电动垂直  起  降飞机，飞行速度  最  高可达到  每  小  时  约320  公  里，一  次  充电  后  的  续  航  里  程超过240公里。job##ya##via##tion称，因  为  这款飞机采用了电  动  传  动    系  统和多旋翼设计，  它  [UNK]在  起  飞和降落时比  传  统飞机安静100倍，[SEP]与传统  直  升机相比，[SEP]
#
#
# |      305/1000000000 steps| 141926.09 tokens/s| loss   10.67| loss_mlm: 9.982| loss_sp: 0.686| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]到[MASK]国海军[MASK]这方面缺[MASK]实[MASK]使用经验[MASK]因此该项目[MASK]终停止发展并转为[MASK]术储备。而在经过了[MASK]30余年的沉[MASK]之后，国产水面舰艇[MASK]角反射器诱饵领  域  的应用才有了 tour的突破。藉由[MASK]  撥  媒[MASK]发布的相关照片，[SEP][MASK]连美国海军也曾经在80年[MASK][MASK]期引进过dl##f-1[MASK]橡皮鸭[UNK]漂浮式诱饵，[SEP]
#
# 填入预测词后的文本：
# [CLS]到 matt国海军  藿  这方面缺international实 ##汩 使用经验  ∀  因此该项目 ##hn终停止发展并转为 ##] 术储备。而在经过了  遒  30余年的沉 ##螢 之后，国产水面舰艇 ##这 角反射器诱饵领  愕  的应用才有了 ##缨 的突破。藉由 ##メ  ##过 媒  フ  发布的相关照片，[SEP] ##繡 连美国海军也曾经在80年 ##鴿  ##cn期引进过dl##f-1##key橡皮鸭[UNK]漂浮式诱饵，[SEP]
#
# 原始文本(目标文本)
# [CLS]到  我  国海军  在  这方面缺  乏  实  际  使用经验  ，  因此该项目  最  终停止发展并转为  技  术储备。而在经过了  近  30余年的沉  寂  之后，国产水面舰艇  在  角反射器诱饵领  域  的应用才有了  新  的突破。藉由  官    方  媒  体  发布的相关照片，[SEP]  就  连美国海军也曾经在80年  代    中  期引进过dl##f-1[UNK]橡皮鸭[UNK]漂浮式诱饵，[SEP]
#
#
# |      310/1000000000 steps| 137728.85 tokens/s| loss   10.67| loss_mlm: 9.965| loss_sp: 0.707| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]-  腼  究建立制造业[MASK]融合作的[MASK]名[MASK]；[SEP]但长远来看[MASK]这[MASK][MASK]新能源汽车发展的机遇，可以倒逼我们的汽车企业加大创新力度[MASK]加快转型[MASK]力度。总[MASK]来看，有  符  于中国汽车市场走向国际化。  下  [MASK]步，我们将秉持开放[MASK]作的理念，坚持  市  场化的导向，加[MASK]品[MASK]培育，努力提质[MASK]  效  ，提高[SEP]
#
# 填入预测词后的文本：
# [CLS]- ##稱 究建立制造业  も  融合作的 ##繡 名curve；[SEP]但长远来看  苹  这  估   ##cn新能源汽车发展的机遇，可以倒逼我们的汽车企业加大创新力度  gs 加快转型##public力度。总  结  来看，有  瞰  于中国汽车市场走向国际化。 ##裆   めた 步，我们将秉持开放  25 作的理念，坚持 ##欧 场化的导向，加 ##呗 品 ##淩 培育，努力提质 ##霆  man ，提高[SEP]
#
# 原始文本(目标文本)
# [CLS]-  研  究建立制造业  产  融合作的  白  名  单  ；[SEP]但长远来看  ，  这  也    是  新能源汽车发展的机遇，可以倒逼我们的汽车企业加大创新力度  ，  加快转型  的  力度。总  体  来看，有  助  于中国汽车市场走向国际化。  下    一  步，我们将秉持开放  合  作的理念，坚持  市  场化的导向，加  快  品  牌  培育，努力提质  增    效  ，提高[SEP]
#
#
# |      315/1000000000 steps| 135805.91 tokens/s| loss   10.71| loss_mlm: 10.009| loss_sp: 0.696| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]s##z）股份等[MASK]天眼查资料显示[MASK]京东数科成立于2012年9月，[SEP]持股比[MASK]为14.67%；第二大股东为刘强东  八  人，[MASK]股[MASK]例为14.  02 %，公 www 最终受益人 ##絡 刘强东。  爾  开资料显示，京东金融[MASK]胎于京东[MASK][MASK]2013年10月京东金融开始独立[MASK][MASK]，[MASK]年[MASK]月[MASK]式完成vi##e拆分成为独立个体，  鹧  年[SEP]
#
# 填入预测词后的文本：
# [CLS]s##z）股份等  ∀  天眼查资料显示 ##禾 京东数科成立于2012年9月，[SEP]持股比##580为14.67%；第二大股东为刘强东economy人，  觊  股 ##紜 例为14.  崖  %，公 ##誅 最终受益人 ##伞 刘强东。  芒  开资料显示，京东金融  檻  胎于京东  劏   274 2013年10月京东金融开始独立  籼   ##呗 ， ##馁 年 ##摺 月 ##罡 式完成vi##e拆分成为独立个体，  饭  年[SEP]
#
# 原始文本(目标文本)
# [CLS]s##z）股份等  。  天眼查资料显示  ，  京东数科成立于2012年9月，[SEP]持股比  例  为14.67%；第二大股东为刘强东  本  人，  持  股  比  例为14.  02 %，公  司  最终受益人  为  刘强东。  公  开资料显示，京东金融  脱  胎于京东  ，    于  2013年10月京东金融开始独立  运    营  ， 2017年  8  月  正  式完成vi##e拆分成为独立个体， 2018年[SEP]
# |      320/1000000000 steps| 125804.64 tokens/s| loss   10.68| loss_mlm: 9.975| loss_sp: 0.705| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]成一致。包括欧洲在内[MASK][MASK]他所[MASK]国家对美国的高额[MASK]偿[MASK]是持保留态度[MASK]。另外，保护知识产权[MASK]能只靠惩罚性赔偿，还有很多其[MASK]方面的工作可做，预防发生知[MASK]产权[MASK]权[MASK]  v8 。徐宏接受采[MASK]记[MASK]：[MASK]人担心，虽然中国的法律法[MASK]有[MASK]进，[SEP]但执  噔  力度有待[MASK]强。您对此有何看法？[SEP]
#
# 填入预测词后的文本：
# [CLS]成一致。包括欧洲在内 ##汩   崖  他所 ##聯 国家对美国的高额 ##勢 偿  喟  是持保留态度 ##⑩ 。另外，保护知识产权  滩  能只靠惩罚性赔偿，还有很多其  嘭  方面的工作可做，预防发生知  帐  产权 ##腭 权  帐    统  。徐宏接受采 ##啕 记  人  ： ##侶 人担心，虽然中国的法律法 ##ke有 ##メ 进，[SEP]但执 skip力度有待  掲  强。您对此有何看法？[SEP]
#
# 原始文本(目标文本)
# [CLS]成一致。包括欧洲在内  的    其  他所  有  国家对美国的高额  赔  偿  都  是持保留态度  的  。另外，保护知识产权  不  能只靠惩罚性赔偿，还有很多其  他  方面的工作可做，预防发生知  识  产权  侵  权  行    为  。徐宏接受采  访  记  者  ：  有  人担心，虽然中国的法律法  规  有  改  进，[SEP]但执  法  力度有待  加  强。您对此有何看法？[SEP]
#
#
# |      325/1000000000 steps| 124714.94 tokens/s| loss   10.67| loss_mlm: 9.987| loss_sp: 0.684| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]郭荣铿利用自己内会副主席的身份，主持内会  主  席[MASK]举，放任[MASK]党互相提[MASK]，搞出[MASK]内务[MASK]员会主席候[MASK]人竟[MASK][MASK]个这样  ก  闹剧。郭荣铿[SEP]更有甚者，[MASK]荣铿[MASK]允许反[MASK]派议员作超[MASK][MASK]间的发言，[MASK][MASK]一场[MASK]称史无前例的最大拉布，导致本年度的立法会内务委员 ##$ 开会4个月内共12次会[SEP]
#
# 填入预测词后的文本：
# [CLS]郭荣铿利用自己内会副主席的身份，主持内会  澹  席 ##舜 举，放任  瀑  党互相提 ##] ，搞出  喟  内务 105 员会主席候 274 人竟 ##牺   遒  个这样  ｘ  闹剧。郭荣铿[SEP]更有甚者，##key荣铿  島  允许反 ##鳅 派议员作超 ##偻  ##˚ 间的发言， ##淩   杉  一场  极  称史无前例的最大拉布，导致本年度的立法会内务委员  凝  开会4个月内共12次会[SEP]
#
# 原始文本(目标文本)
# [CLS]郭荣铿利用自己内会副主席的身份，主持内会  主  席  选  举，放任  同  党互相提  名  ，搞出  了  内务  委  员会主席候  选  人竟  有    23 个这样  的  闹剧。郭荣铿[SEP]更有甚者，  郭  荣铿  还  允许反  对  派议员作超  长    时  间的发言，  掀    起  一场  堪  称史无前例的最大拉布，导致本年度的立法会内务委员  会  开会4个月内共12次会[SEP]
#
#
# |      330/1000000000 steps| 143079.13 tokens/s| loss   10.68| loss_mlm: 9.990| loss_sp: 0.691| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS][MASK][MASK]日新月异。这不，在护卫舰领域[MASK][SEP]一款性能更先  进  、吨位更大的型[MASK]，[SEP]
#
# 填入预测词后的文本：
# [CLS]financial ##ᅭ 日新月异。这不，在护卫舰领域  ╚  [SEP]一款性能更先 ##ｂ 、吨位更大的型 ##呗 ，[SEP]
#
# 原始文本(目标文本)
# [CLS]  真    是  日新月异。这不，在护卫舰领域  ，  [SEP]一款性能更先  进  、吨位更大的型  号  ，[SEP]
#
#
# |      335/1000000000 steps| 148013.77 tokens/s| loss   10.67| loss_mlm: 9.964| loss_sp: 0.710| acc_mlm: 0.000| acc_sp: 0.200
# 输入的处理后文本：
# [CLS]始  ，  [MASK]就很荣幸能与佩奇[MASK]布林一起工作，帮助实现他们的承诺[MASK][MASK]让信息更普遍地可访问[MASK]使用  ，  并很高兴能在2002[MASK]全职加盟谷歌。随着佩奇和布林辞去alpha##bet的高管职位，公司正进入[MASK]个激[MASK]人心[MASK]新阶段，[MASK]相信，现[MASK]也是我为下[MASK]代领导人  让  位的好时机。因[MASK]，[SEP]经[MASK][MASK][MASK]考虑，[SEP]
#
# 填入预测词后的文本：
# [CLS]始  咽    桓  就很荣幸能与佩奇 ##汩 布林一起工作，帮助实现他们的承诺  桓   ##浄 让信息更普遍地可访问  诞  使用  编  并很高兴能在2002 ##揃 全职加盟谷歌。随着佩奇和布林辞去alpha##bet的高管职位，公司正进入 ##侖 个激  遒  人心 ##勢 新阶段， ##侶 相信，现  遒  也是我为下  桓  代领导人 ##顿 位的好时机。因  瀑  ，[SEP]经 ##委   桐   ##赐 考虑，[SEP]
#
# 原始文本(目标文本)
# [CLS]始  ，    我  就很荣幸能与佩奇  和  布林一起工作，帮助实现他们的承诺[UNK][UNK]让信息更普遍地可访问  和  使用  ，  并很高兴能在2002  年  全职加盟谷歌。随着佩奇和布林辞去alpha##bet的高管职位，公司正进入  一  个激  动  人心  的  新阶段，  我  相信，现  在  也是我为下  一  代领导人  让  位的好时机。因  此  ，[SEP]经  过    慎    重  考虑，[SEP]
#
#
# |      340/1000000000 steps| 145467.97 tokens/s| loss   10.62| loss_mlm: 9.940| loss_sp: 0.677| acc_mlm: 0.000| acc_sp: 0.800
# 输入的处理后文本：
# [CLS]有点偏[MASK]色的[MASK]果红，特  别  显白显气色  的  颜[MASK]，[MASK]级甜超级嫩的一[MASK]日常色，可以说[MASK]直男的[MASK][MASK]了。质地非常的顺滑，显色度高，哑光质地容易拨干。[SEP][MASK]##ko1、k##iko416色调：樱桃[MASK][MASK]级显白的一个[MASK]桃红色，[MASK]点  绳  棕色，让你气场全开的颜色[MASK]质地非常非常的滋[MASK]顺滑，很好上[MASK]。[SEP]
#
# 填入预测词后的文本：
# [CLS]有点偏  溝  色的 ##逅 果红，特  亢  显白显气色##map颜  喟  ，  讶  级甜超级嫩的一 ##浄 日常色，可以说 ##團 直男的 ##肋   遒  了。质地非常的顺滑，显色度高，哑光质地容易拨干。[SEP]##hen##ko1、k##iko416色调：樱桃 ##к   掲  级显白的一个  檻  桃红色，  喟  点  雕  棕色，让你气场全开的颜色 llc 质地非常非常的滋 ##籁 顺滑，很好上  牵  。[SEP]
#
# 原始文本(目标文本)
# [CLS]有点偏  橘  色的  苹  果红，特  别  显白显气色  的  颜  色  ，  超  级甜超级嫩的一  个  日常色，可以说  是  直男的  斩    色  了。质地非常的顺滑，显色度高，哑光质地容易拨干。[SEP]  li ##ko1、k##iko416色调：樱桃  红    超  级显白的一个  樱  桃红色，  带  点  点  棕色，让你气场全开的颜色  ，  质地非常非常的滋  润  顺滑，很好上  色  。[SEP]
#
#
# |      345/1000000000 steps| 139844.39 tokens/s| loss   10.73| loss_mlm: 10.015| loss_sp: 0.714| acc_mlm: 0.000| acc_sp: 0.000
# 输入的处理后文本：
# [CLS][MASK][MASK]卫健委：新型冠状病毒感  染  的[MASK]炎疫情可防可控据国家卫生[MASK]康委官网消息[MASK]专家研判认为，当前疫情仍[MASK]防可[MASK]。[SEP][MASK]新型冠状病毒传染来源尚未找到，疫情传播途径尚[MASK]完全掌握，[MASK]毒变异仍需严密监控[MASK]  踵  于武汉病 ##68性[MASK]炎，这5大谣言千万别信[MASK][MASK]看  中  国疾病[MASK]防控制中心[SEP]
#
# 填入预测词后的文本：
# [CLS]  蹂   ##ね 卫健委：新型冠状病毒感  雕  的  ∀  炎疫情可防可控据国家卫生  桓  康委官网消息 ##嚨 专家研判认为，当前疫情仍  囹  防可 ##ⓔ 。[SEP]  胶  新型冠状病毒传染来源尚未找到，疫情传播途径尚 exe 完全掌握，  喟  毒变异仍需严密监控  喟   uhz 于武汉病 ##ない性 ##cn炎，这5大谣言千万别信hotel ##汩 看 073 国疾病 ##呗 防控制中心[SEP]
#
# 原始文本(目标文本)
# [CLS]  国    家  卫健委：新型冠状病毒感  染  的  肺  炎疫情可防可控据国家卫生  健  康委官网消息  ，  专家研判认为，当前疫情仍  可  防可  控  。[SEP]  但  新型冠状病毒传染来源尚未找到，疫情传播途径尚  未  完全掌握，  病  毒变异仍需严密监控  。    关  于武汉病  毒  性  肺  炎，这5大谣言千万别信  ！    来  看  中  国疾病  预  防控制中心[SEP]
#
#
# |      350/1000000000 steps| 128557.96 tokens/s| loss   10.67| loss_mlm: 9.992| loss_sp: 0.675| acc_mlm: 0.000| acc_sp: 1.000
# 输入的处理后文本：
# [CLS]然而风险[MASK]然存在[UNK]。[MASK]2011年[MASK]约国[MASK]以空袭政府军的方式，强行[MASK]翻卡扎菲政[MASK]以来，利比亚  一  直处于 ##駐 [MASK][MASK]中。[SEP]由[UNK]利比亚民族团结[MASK]府[UNK]与支持其的武装力量控制着西部地区[MASK]国[MASK]代表大[MASK]在东部地区另[MASK]政府，[MASK]哈夫塔尔领##ider的[UNK]国民军[UNK]共同  简  制着东部和中部地区、南部主[SEP]
#
# 填入预测词后的文本：
# [CLS]然而风险 ##イト然存在[UNK]。tokichoi2011年  遒  约国  喟  以空袭政府军的方式，强行  喟  翻卡扎菲政 ##嚨 以来，利比亚 ##嚨 直处于  爪   105   啜  中。[SEP]由[UNK]利比亚民族团结  厌  府[UNK]与支持其的武装力量控制着西部地区 ##呗 国 ssd 代表大##580在东部地区另 ##鹤 政府， ##呗 哈夫塔尔领  讼  的  n1 国民军[UNK]共同 ##霏 制着东部和中部地区、南部主[SEP]
#
# 原始文本(目标文本)
# [CLS]然而风险  仍  然存在[UNK]。  自  2011年  北  约国  家  以空袭政府军的方式，强行  推  翻卡扎菲政  府  以来，利比亚  一  直处于  动    荡    之  中。[SEP]由[UNK]利比亚民族团结  政  府[UNK]与支持其的武装力量控制着西部地区  ；  国  民  代表大  会  在东部地区另  建  政府，  与  哈夫塔尔领  导  的[UNK]国民军[UNK]共同  控  制着东部和中部地区、南部主[SEP]
# |      355/1000000000 steps| 126468.66 tokens/s| loss   10.70| loss_mlm: 10.002| loss_sp: 0.697| acc_mlm: 0.000| acc_sp: 0.400
# 输入的处理后文本：
# [CLS]升[MASK]了50000##0平方米。在  具  体使用方式上，我们以最新的dl[MASK]-3/[MASK]-59为例。首先，当舰载雷[MASK]告警系统截获[MASK]来袭导[MASK]导引头的雷[MASK]信号，[SEP][MASK]由退役舰[MASK]发挥余热[MASK]造而来的大[MASK]靶船以外，排[MASK]量较小的海上固定[MASK]  标  平台或自航式  幽    控    す  船也是各国海军军辅船序列中极为重  要  的组[SEP]
#
# 填入预测词后的文本：
# [CLS]升 ##浄 了50000##0平方米。在 ##螢 体使用方式上，我们以最新的dl ##佶 -3/  喟  -59为例。首先，当舰载雷  遒  告警系统截获  亙  来袭导 ##腭 导引头的雷 ##硒 信号，[SEP] ##雞 由退役舰  檻  发挥余热 ##郤 造而来的大 ##呗 靶船以外，排 ##籁 量较小的海上固定 ##愫   檻  平台或自航式 ##進 aphojoy ##υ 船也是各国海军军辅船序列中极为重  渤  的组[SEP]
#
# 原始文本(目标文本)
# [CLS]升  到  了50000##0平方米。在  具  体使用方式上，我们以最新的dl ##f -3/  mk -59为例。首先，当舰载雷  达  告警系统截获  到  来袭导  弹  导引头的雷  达  信号，[SEP]  经  由退役舰  船  发挥余热  改  造而来的大  中  靶船以外，排  水  量较小的海上固定  靶    标  平台或自航式  遥    控    靶  船也是各国海军军辅船序列中极为重  要  的组[SEP]
#
#
# |      360/1000000000 steps| 130313.81 tokens/s| loss   10.66| loss_mlm: 9.970| loss_sp: 0.686| acc_mlm: 0.000| acc_sp: 0.600
# 输入的处理后文本：
# [CLS]图片来自网络 ##広 如[MASK]侵权，请联系我们删除，谢谢  鉑  [SEP]再搭配[MASK]一款[MASK][MASK]夸张的项[MASK]，更是能够让霍思燕的颈部[MASK]得更加  的  修长优美。声明：文字  ☼  创，[SEP]
#
# 填入预测词后的文本：
# [CLS]图片来自网络##rth如 ##侶 侵权，请联系我们删除，谢谢 ##镜 [SEP]再搭配  亟  一款  檻  ##580夸张的项  檻  ，更是能够让霍思燕的颈部 ##委 得更加 ##再 修长优美。声明：文字  ¼  创，[SEP]
#
# 原始文本(目标文本)
# [CLS]图片来自网络  。  如  有  侵权，请联系我们删除，谢谢  。  [SEP]再搭配  上  一款  较    为  夸张的项  链  ，更是能够让霍思燕的颈部  显  得更加  的  修长优美。声明：文字  原  创，[SEP]
